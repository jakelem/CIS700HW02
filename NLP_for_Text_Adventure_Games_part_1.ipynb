# %% [markdown]
# <a href="https://colab.research.google.com/github/jakelem/CIS700HW02/blob/master/NLP_for_Text_Adventure_Games_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP for Text Adventure Games - part 1
#
# In this notebook, we start trying to improve the coverage of the parser in a text adventure game like Action Castle.  The parser is responsible for interpreting the players' input.  A limitation of classic text adventure games was that parsers were able to handle only a limited number of keywords, and did not support the wide range of different ways that it is possible to say a command.  This is one of the key components that makes natural language challenging for computers to handle.
#
# In part 1, we will introduce you to the WordNet resource.  WordNet is a classic resource for natural language processing.  It was created at Princeton University by Chrstine Fellbaum and Geroge Miller.  It encodes information about synonyms, antonyms, and is-a relationships between words like _troll_ is-a _monster_.  In NLP, is-a relationships are called hypernyms or hyponyms.

# %% [markdown]
# # WordNet
# [WordNet](https://wordnet.princeton.edu) is a lexical knowledge base that encodes a ton of useful information about how words relate to each other.  NLTK provides a Python API to WordNet.

# %%
#!sudo pip3 install nltk 
import nltk
nltk.download('wordnet')
nltk.download('punkt')
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ## Word Senses
# Words with multiple meanings are called _polysemous_ words.  An example of a polysemous word is the word _bug_ which can mean
# 1. an insect
# 2. a virus or microbe that makes you sick
# 3. an error in your computer program
# 4. a covert listening device
# 5. (verb) to annoy/bother
# 6. (verb) to wiretap
#
# WordNet oraganizes word senses into a structure called _synsets_. Each word can have multiple synsets, and each synset represents a different meaning of the word.

# %%
def get_senses(word):
  """Returns a list of word senses (WordNet synsets) for a word"""
  word_senses = wn.synsets(word)
  return word_senses

def get_definition(word_sense):
  return word_sense.definition()

def get_synonyms(word_sense):
  synonyms = []
  for lemma in word_sense.lemmas():
    synonym = lemma.name().replace('_', ' ')
    synonyms.append(synonym)
  return synonyms

#Here are the word senses for "bug". We can see what their distinct meanings are 
#by getting their definitions or their synonyms from WordNet.
word_senses = get_senses("bug")
for i, word_sense in enumerate(word_senses):
  print("\nSense %d: %s" % (i, word_sense.name()))
  print("Definition: ", get_definition(word_sense))
  print("Synonyms: ", get_synonyms(word_sense))
# Out:
# Sense 0: bug.n.01
# Definition:  general term for any insect or similar creeping or crawling invertebrate
# Synonyms:  ['bug']
#
# Sense 1: bug.n.02
# Definition:  a fault or defect in a computer program, system, or machine
# Synonyms:  ['bug', 'glitch']
#
# Sense 2: bug.n.03
# Definition:  a small hidden microphone; for listening secretly
# Synonyms:  ['bug']
#
# Sense 3: hemipterous_insect.n.01
# Definition:  insects with sucking mouthparts and forewings thickened and leathery at the base; usually show incomplete metamorphosis
# Synonyms:  ['hemipterous insect', 'bug', 'hemipteran', 'hemipteron']
#
# Sense 4: microbe.n.01
# Definition:  a minute life form (especially a disease-causing bacterium); the term is not in technical use
# Synonyms:  ['microbe', 'bug', 'germ']
#
# Sense 5: tease.v.01
# Definition:  annoy persistently
# Synonyms:  ['tease', 'badger', 'pester', 'bug', 'beleaguer']
#
# Sense 6: wiretap.v.01
# Definition:  tap a telephone or telegraph wire to get information
# Synonyms:  ['wiretap', 'tap', 'intercept', 'bug']

# %% [markdown]
# ## Hypernyms / Hyponyms
#
# In addition to representing word senses, WordNet also organizes words hierachically. For example, _red_ is a specific kind of _color_, or _microbe_ is a kind of _organism_.  These are example of _hyponym_ relationships.  If X is-a Y then X is a hyponym of Y, and Y is a hypernym of X. So _red_ is a hyponym of _color_ and _color_ is a hypernym of _red_.
#
# In WordNet, each word sense (synset) has its own distinct hypernyms and hyponyms.

# %%
hyper = lambda s: s.hypernyms()
hypo = lambda s: s.hyponyms()

def get_hypernyms(word_sense, depth=5):
  return list(word_sense.closure(hyper, depth=depth))

def get_hyponyms(word_sense, depth=5):
  return list(word_sense.closure(hypo, depth=depth))

word_senses = get_senses("bug")
for i, word_sense in enumerate(word_senses):
  # The synset names include a word from the set of synonyms, 
  # plus a part of speech (n for noun, v for verb), and 
  # the number of the sense (sense 01 is the most common sense).
  print("\nSense %d: %s (%s)" % (i, word_sense.name(), get_definition(word_sense)))
  print("Hypernyms:")
  hypernyms = word_sense.hypernyms()
  while len(hypernyms) >0:
    print("%s\tis a\t%s" % (word_sense.name(), hypernyms[0].name()))
    word_sense = hypernyms[0]
    hypernyms = word_sense.hypernyms()
# Out:
# Sense 0: bug.n.01 (general term for any insect or similar creeping or crawling invertebrate)
# Hypernyms:
# bug.n.01	is a	insect.n.01
# insect.n.01	is a	arthropod.n.01
# arthropod.n.01	is a	invertebrate.n.01
# invertebrate.n.01	is a	animal.n.01
# animal.n.01	is a	organism.n.01
# organism.n.01	is a	living_thing.n.01
# living_thing.n.01	is a	whole.n.02
# whole.n.02	is a	object.n.01
# object.n.01	is a	physical_entity.n.01
# physical_entity.n.01	is a	entity.n.01
#
# Sense 1: bug.n.02 (a fault or defect in a computer program, system, or machine)
# Hypernyms:
# bug.n.02	is a	defect.n.03
# defect.n.03	is a	imperfection.n.01
# imperfection.n.01	is a	state.n.02
# state.n.02	is a	attribute.n.02
# attribute.n.02	is a	abstraction.n.06
# abstraction.n.06	is a	entity.n.01
#
# Sense 2: bug.n.03 (a small hidden microphone; for listening secretly)
# Hypernyms:
# bug.n.03	is a	microphone.n.01
# microphone.n.01	is a	electro-acoustic_transducer.n.01
# electro-acoustic_transducer.n.01	is a	transducer.n.01
# transducer.n.01	is a	electrical_device.n.01
# electrical_device.n.01	is a	device.n.01
# device.n.01	is a	instrumentality.n.03
# instrumentality.n.03	is a	artifact.n.01
# artifact.n.01	is a	whole.n.02
# whole.n.02	is a	object.n.01
# object.n.01	is a	physical_entity.n.01
# physical_entity.n.01	is a	entity.n.01
#
# Sense 3: hemipterous_insect.n.01 (insects with sucking mouthparts and forewings thickened and leathery at the base; usually show incomplete metamorphosis)
# Hypernyms:
# hemipterous_insect.n.01	is a	insect.n.01
# insect.n.01	is a	arthropod.n.01
# arthropod.n.01	is a	invertebrate.n.01
# invertebrate.n.01	is a	animal.n.01
# animal.n.01	is a	organism.n.01
# organism.n.01	is a	living_thing.n.01
# living_thing.n.01	is a	whole.n.02
# whole.n.02	is a	object.n.01
# object.n.01	is a	physical_entity.n.01
# physical_entity.n.01	is a	entity.n.01
#
# Sense 4: microbe.n.01 (a minute life form (especially a disease-causing bacterium); the term is not in technical use)
# Hypernyms:
# microbe.n.01	is a	microorganism.n.01
# microorganism.n.01	is a	organism.n.01
# organism.n.01	is a	living_thing.n.01
# living_thing.n.01	is a	whole.n.02
# whole.n.02	is a	object.n.01
# object.n.01	is a	physical_entity.n.01
# physical_entity.n.01	is a	entity.n.01
#
# Sense 5: tease.v.01 (annoy persistently)
# Hypernyms:
# tease.v.01	is a	torment.v.02
# torment.v.02	is a	harass.v.01
# harass.v.01	is a	annoy.v.01
# annoy.v.01	is a	displease.v.01
#
# Sense 6: wiretap.v.01 (tap a telephone or telegraph wire to get information)
# Hypernyms:
# wiretap.v.01	is a	listen_in.v.02
# listen_in.v.02	is a	listen.v.01
# listen.v.01	is a	perceive.v.01

# %% [markdown]
# ## Text Adventure Commands
# One of the tricky things about creating a text adventure game is anticipating the many different ways that a player might write a command.
#
# If you program the game to understand a command like _give fish to troll_ and the player types in _feed fish to troll_, then a simple parser will fail to undertand the command.
#
# Here we're going to use WordNet to expand out the set of commands that we've programed into the game, with the goal of being able to recognize more varied input from the player.
#
# Instead of just one _give fish to troll_ command, we'll enumerate thouands of alternatives like
#
# * _serve salmon to monster_
# * _serve up food to monster_
# * _feed sea trout to troll_
# * _supply smoked salmon to mythical creature_

# %%
commands = [
	'wear crown',
	'smell rose',
	'eat fish',
	'light lamp',
	'give fish to troll',
	'propose to the princess',
	'go north',
]

# %% [markdown]
# ## Manually Annotate Senses and Hypernyms/Hyponyms
#
# Below is some code that will help you manually annotate the word sense of each word in your list of commands, and confirm which hypernyms and hyponyms are reasonable substitutes that should be recognized if a player types them instead of our command word.

# %% [markdown]
# Here are some helper functions for you. You can just run this cell instead of reading through the functions in detail if you want.

# %%
def annotate_synsets(sentences):
  """This function queries WordNet for each word in a list of sentences,
     and asks the user to input a number corresponding to the synset."""

  word_senses = {}
  # Cached selections maps from word string to the previous
  # selection for this word (an integer)
  cached_selections = {}

  for i, sent in enumerate(sentences):
    words = word_tokenize(sent.lower())

    for word in words:
      sysnsets = wn.synsets(word)
      if len(sysnsets) != 0:
        selection = select_synset(sent, word, sysnsets, cached_selections)
        if selection != None:
          cached_selections[word] = selection
          if selection < len(sysnsets):
            s = sysnsets[selection]
            word_senses[word] = s.name()
  return word_senses


def select_synset(sent, word, sysnsets, cached_selections):
  """Ask the user to select which sense of the word  
     is being used in this sentence."""
  print(sent)
  print(word.upper())

  prev_selection = -1
  if word in cached_selections:
    prev_selection = cached_selections[word]

  for choice, s in enumerate(sysnsets):
    if choice == prev_selection:
      print("*** ", end = '')
    print("%d) %s - %s" % (choice, s.name(), s.definition()))

  choice += 1
  if choice == prev_selection:
    print("*** ", end = '')
  print("%d None of these." % choice)

  selection = -1
  while selection == -1:
    try:
      user_input = input(">")
      if user_input.strip() == 'x':
        # The user can press 'x' to exit.
        return None
      if user_input.strip() == '' and prev_selection > -1:
        # The user can press retrun to confirm the previous selection.
        return prev_selection
      selection = int(user_input)
    except:
      selection = -1
    if selection < 0 or selection > len(sysnsets):
      print("Please select a number between 0-%d, or type 'x' to exit" % len(sysnsets))
      if prev_selection > -1:
        print("You can also press return to confirm the previous selection (marked by ***).")
    else:
      return selection


def confirm_hyponyms(word, sysnset, do_hypernyms_instead=False):
  """Ask the user to confirm which of the hyponyms are applicable 
     for this sentence."""
  print(word.upper())

  confirmed = []
  if do_hypernyms_instead:
    unconfirmed = sysnset.hypernyms()
  else:
    unconfirmed = sysnset.hyponyms()

  while len(unconfirmed) > 0:
    s = unconfirmed.pop(0)
    print("Is %s an appropriate substitute for %s? (y/n)" % (s.name(), word))
    print("It means:", s.definition())
    print("Synonyms are:", get_synonyms(s))
    user_input = ''
    while user_input == '':
      user_input = input(">")
      user_input = user_input.strip()
      if user_input == 'y' or user_input == 'yes':
        confirmed.append(s.name())
        if do_hypernyms_instead:
          unconfirmed.extend(s.hypernyms())
        else:
          unconfirmed.extend(s.hyponyms())
        
      elif user_input == 'n' or user_input == 'no':
        pass
      elif user_input == 'x':
        # The user can press 'x' to exit.
        return confirmed
      else:
        print("Please type 'yes' or 'no' or 'x' to stop confirming for this word")
        user_input = ''
  return confirmed

# Save your annotations to a file, so that you can submit them with your homework.
def save_to_drive(word_senses, confirmed_hyponyms, confirmed_hypernyms):
  import json
  from google.colab import drive
  drive.mount('/content/drive/')

  output_file = '/content/drive/My Drive/word-sense-annotations.json'
  output_json = {}
  output_json['senses'] = word_senses
  output_json['hyponyms'] = confirmed_hyponyms
  output_json['hypernyms'] = confirmed_hypernyms

  with open(output_file, 'w') as write_file:
    write_file.write(json.dumps(output_json, sort_keys=True, indent=4))
    write_file.write('\n')

# %% [markdown]
# Run this part when you're ready to start annotating the words in the commands. I estimate that it will take about 10 minutes per command.  Your annotations will be saved to a file in your Google Drive called _word-sense-annotations.json_, so that you can submit them with your homework.  You'll be prompted to enter a code to authorize Colab to write to your Google Drive. Be sure to do this so that your work will be saved.

# %%
word_senses = annotate_synsets(commands)
confirmed_hyponyms = {}
confirmed_hypernyms = {}
for word in word_senses:
  print("First, pick the word sense for the word '%s'" % word)
  print("==============")
  word_sense = wn.synset(word_senses[word])
  print("\nNext, pick which hypernyms of %s we should allow players to use." % word_sense.name())
  print("==============")
  confirmed_hypernyms[word] = confirm_hyponyms(word, word_sense, do_hypernyms_instead=True)
  print("\Finally, pick which hyponyms of %s we should allow players to use." % word_sense.name())
  print("==============")  
  confirmed_hyponyms[word] = confirm_hyponyms(word, word_sense)


print("You're done annotating!  Save your annotation to your Google drive.")
print("You need to paste in a confirmation code to allow Colab to have access.")
print("We'll create a file called 'word-sense-annotations.json' for you to turn in.")
print("==============")
save_to_drive(word_senses, confirmed_hyponyms, confirmed_hypernyms)
# Out:
# wear crown
# WEAR
# 0) wear.n.01 - impairment resulting from long use
# 1) clothing.n.01 - a covering designed to be worn on a person's body
# 2) wear.n.03 - the act of having on your person as a covering or adornment
# 3) wear.v.01 - be dressed in
# 4) wear.v.02 - have on one's person
# 5) wear.v.03 - have in one's aspect; wear an expression of one's attitude or personality
# 6) wear.v.04 - deteriorate through use or stress
# 7) wear.v.05 - have or show an appearance of
# 8) wear.v.06 - last and be usable
# 9) break.v.42 - go to pieces
# 10) tire.v.02 - exhaust or get tired through overuse or great strain or stress
# 11) wear.v.09 - put clothing on one's body
# 12 None of these.
# >11
# wear crown
# CROWN
# 0) crown.n.01 - the Crown (or the reigning monarch) as the symbol of the power and authority of a monarchy
# 1) crown.n.02 - the part of a tooth above the gum that is covered with enamel
# 2) crown.n.03 - a wreath or garland worn on the head to signify victory
# 3) crown.n.04 - an ornamental jeweled headdress signifying sovereignty
# 4) crown.n.05 - the part of a hat (the vertex) that covers the crown of the head
# 5) crown.n.06 - an English coin worth 5 shillings
# 6) crown.n.07 - the upper branches and leaves of a tree or other plant
# 7) peak.n.04 - the top or extreme point of something (usually a mountain or hill)
# 8) pennant.n.01 - the award given to the champion
# 9) pate.n.02 - the top of the head
# 10) crown.n.11 - (dentistry) dental appliance consisting of an artificial crown for a broken or decayed tooth
# 11) crown.n.12 - the center of a cambered road
# 12) crown.v.01 - invest with regal power; enthrone
# 13) crown.v.02 - be the culminating event
# 14) crown.v.03 - form the topmost part of
# 15) crown.v.04 - put an enamel cover on
# 16 None of these.
# >2
# smell rose
# SMELL
# 0) smell.n.01 - the sensation that results when olfactory receptors in the nose are stimulated by particular chemicals in gaseous form
# 1) olfactory_property.n.01 - any property detected by the olfactory system
# 2) spirit.n.02 - the general atmosphere of a place or situation and the effect that it has on people
# 3) smell.n.04 - the faculty that enables us to distinguish scents
# 4) smell.n.05 - the act of perceiving the odor of something
# 5) smell.v.01 - inhale the odor of; perceive by the olfactory sense
# 6) smell.v.02 - emit an odor
# 7) smell.v.03 - smell bad
# 8) smack.v.02 - have an element suggestive (of something)
# 9) smell.v.05 - become aware of not through the senses but instinctively
# 10 None of these.
# >5
# smell rose
# ROSE
# 0) rose.n.01 - any of many shrubs of the genus Rosa that bear roses
# 1) blush_wine.n.01 - pinkish table wine from red grapes whose skins were removed after fermentation began
# 2) rose.n.03 - a dusty pink color
# 3) rise.v.01 - move upward
# 4) rise.v.02 - increase in value or to a higher point
# 5) arise.v.03 - rise to one's feet
# 6) rise.v.04 - rise up
# 7) surface.v.01 - come to the surface
# 8) originate.v.01 - come into existence; take on form or shape
# 9) ascend.v.08 - move to a better position in life or to a better job
# 10) wax.v.02 - go up or advance
# 11) heighten.v.01 - become more extreme
# 12) get_up.v.02 - get up and out of bed
# 13) rise.v.11 - rise in rank or status
# 14) rise.v.12 - become heartened or elated
# 15) rise.v.13 - exert oneself to meet a challenge
# 16) rebel.v.01 - take part in a rebellion; renounce a former allegiance
# 17) rise.v.15 - increase in volume
# 18) rise.v.16 - come up, of celestial bodies
# 19) resurrect.v.03 - return from the dead
# 20) rose.s.01 - of something having a dusty purplish pink color
# 21 None of these.
# >0
# eat fish
# EAT
# 0) eat.v.01 - take in solid food
# 1) eat.v.02 - eat a meal; take a meal
# 2) feed.v.06 - take in food; used of animals only
# 3) eat.v.04 - worry or cause anxiety in a persistent way
# 4) consume.v.05 - use up (resources or materials)
# 5) corrode.v.01 - cause to deteriorate due to the action of water, air, or an acid
# 6 None of these.
# >1
# eat fish
# FISH
# 0) fish.n.01 - any of various mostly cold-blooded aquatic vertebrates usually having scales and breathing through gills
# 1) fish.n.02 - the flesh of fish used as food
# 2) pisces.n.02 - (astrology) a person who is born while the sun is in Pisces
# 3) pisces.n.01 - the twelfth sign of the zodiac; the sun is in this sign from about February 19 to March 20
# 4) fish.v.01 - seek indirectly
# 5) fish.v.02 - catch or try to catch fish or shellfish
# 6 None of these.
# >0
# light lamp
# LIGHT
# 0) light.n.01 - (physics) electromagnetic radiation that can produce a visual sensation
# 1) light.n.02 - any device serving as a source of illumination
# 2) light.n.03 - a particular perspective or aspect of a situation
# 3) luminosity.n.01 - the quality of being luminous; emitting or reflecting light
# 4) light.n.05 - an illuminated area
# 5) light.n.06 - a condition of spiritual awareness; divine illumination
# 6) light.n.07 - the visual effect of illumination on objects or scenes as created in pictures
# 7) light.n.08 - a person regarded very fondly
# 8) light.n.09 - having abundant light or illumination
# 9) light.n.10 - mental understanding as an enlightening experience
# 10) sparkle.n.01 - merriment expressed by a brightness or gleam or animation of countenance
# 11) light.n.12 - public awareness
# 12) inner_light.n.01 - a divine presence believed by Quakers to enlighten and guide the soul
# 13) light.n.14 - a visual warning signal
# 14) lighter.n.02 - a device for lighting or igniting fuel or charges or fires
# 15) light.v.01 - make lighter or brighter
# 16) light_up.v.05 - begin to smoke
# 17) alight.v.01 - to come to rest, settle
# 18) ignite.v.01 - cause to start burning; subject to fire or great heat
# 19) fall.v.20 - fall to somebody by assignment or lot
# 20) unhorse.v.01 - alight from (a horse)
# 21) light.a.01 - of comparatively little physical weight or density
# 22) light.a.02 - (used of color) having a relatively small amount of coloring agent
# 23) light.a.03 - of the military or industry; using (or being) relatively small or light arms or equipment
# 24) light.a.04 - not great in degree or quantity or number
# 25) light.a.05 - psychologically light; especially free from sadness or troubles
# 26) light.a.06 - characterized by or emitting light
# 27) unaccented.s.02 - (used of vowels or syllables) pronounced with little or no stress
# 28) light.s.08 - easily assimilated in the alimentary canal; not rich or heavily seasoned
# 29) light.s.09 - (used of soil) loose and large-grained in consistency
# 30) clean.s.03 - (of sound or color) free from anything that dulls or dims
# 31) light.s.11 - moving easily and quickly; nimble
# 32) light.s.12 - demanding little effort; not burdensome
# 33) light.a.13 - of little intensity or power or force
# 34) light.a.14 - (physics, chemistry) not having atomic weight greater than average
# 35) faint.s.04 - weak and likely to lose consciousness
# 36) light.s.16 - very thin and insubstantial
# 37) abstemious.s.02 - marked by temperance in indulgence
# 38) light.s.18 - less than the correct or legal or full amount often deliberately so
# 39) light.s.19 - having little importance
# 40) light.s.20 - intended primarily as entertainment; not serious or profound
# 41) idle.s.04 - silly or trivial
# 42) light.s.22 - designed for ease of movement or to carry little weight
# 43) light.s.23 - having relatively few calories
# 44) light.s.24 - (of sleep) easily disturbed
# 45) easy.s.10 - casual and unrestrained in sexual behavior
# 46) lightly.r.02 - with few burdens
# 47 None of these.
# >18
# light lamp
# LAMP
# 0) lamp.n.01 - an artificial source of visible illumination
# 1) lamp.n.02 - a piece of furniture holding one or more electric light bulbs
# 2 None of these.
# >0
# give fish to troll
# GIVE
# 0) give.n.01 - the elasticity of something that can be stretched and returns to its original length
# 1) give.v.01 - cause to have, in the abstract sense or physical sense
# 2) yield.v.01 - be the cause or source of
# 3) give.v.03 - transfer possession of something concrete or abstract to somebody
# 4) give.v.04 - convey or reveal information
# 5) give.v.05 - convey, as of a compliment, regards, attention, etc.; bestow
# 6) hold.v.03 - organize or be responsible for
# 7) give.v.07 - convey or communicate; of a smile, a look, a physical gesture
# 8) give.v.08 - give as a present; make a gift of
# 9) give.v.09 - cause to happen or be responsible for
# 10) give.v.10 - dedicate
# 11) render.v.04 - give or supply
# 12) impart.v.01 - transmit (knowledge or skills)
# 13) establish.v.05 - bring about
# 14) give.v.14 - leave with; give temporarily
# 15) give.v.15 - emit or utter
# 16) sacrifice.v.01 - endure the loss of
# 17) pass.v.05 - place into the hands or custody of
# 18) give.v.18 - give entirely to a specific person, activity, or cause
# 19) give.v.19 - give (as medicine)
# 20) give.v.20 - give or convey physically
# 21) give.v.21 - bestow
# 22) grant.v.05 - bestow, especially officially
# 23) move_over.v.01 - move in order to make room for someone for something
# 24) feed.v.02 - give food to
# 25) contribute.v.02 - contribute to some cause
# 26) collapse.v.01 - break down, literally or metaphorically
# 27) give.v.27 - estimate the duration or outcome of something
# 28) give.v.28 - execute and deliver
# 29) give.v.29 - deliver in exchange or recompense
# 30) afford.v.04 - afford access to
# 31) give.v.31 - present to view
# 32) give.v.32 - perform for an audience
# 33) give.v.33 - be flexible under stress of physical force
# 34) give.v.34 - propose
# 35) give.v.35 - accord by verdict
# 36) give.v.36 - manifest or show
# 37) give.v.37 - offer in good faith
# 38) give.v.38 - submit for consideration, judgment, or use
# 39) give.v.39 - guide or direct, as by behavior of persuasion
# 40) give.v.40 - allow to have or take
# 41) give.v.41 - inflict as a punishment
# 42) give.v.42 - occur
# 43) give.v.43 - consent to engage in sexual intercourse with a man
# 44) give.v.44 - proffer (a body part)
# 45 None of these.
# >3
# give fish to troll
# FISH
# *** 0) fish.n.01 - any of various mostly cold-blooded aquatic vertebrates usually having scales and breathing through gills
# 1) fish.n.02 - the flesh of fish used as food
# 2) pisces.n.02 - (astrology) a person who is born while the sun is in Pisces
# 3) pisces.n.01 - the twelfth sign of the zodiac; the sun is in this sign from about February 19 to March 20
# 4) fish.v.01 - seek indirectly
# 5) fish.v.02 - catch or try to catch fish or shellfish
# 6 None of these.
# >0
# give fish to troll
# TROLL
# 0) troll.n.01 - (Scandanavian folklore) a supernatural creature (either a dwarf or a giant) that is supposed to live in caves or in the mountains
# 1) round.n.11 - a partsong in which voices follow each other; one voice starts and others join in one after another until all are singing different parts of the song at the same time
# 2) troll.n.03 - a fisherman's lure that is used in trolling
# 3) troll.n.04 - angling by drawing a baited line through the water
# 4) troll.v.01 - circulate, move around
# 5) troll.v.02 - cause to move round and round
# 6) troll.v.03 - sing the parts of (a round) in succession
# 7) troll.v.04 - angle with a hook and line drawn through the water
# 8) troll.v.05 - sing loudly and without inhibition
# 9) troll.v.06 - praise or celebrate in song
# 10) troll.v.07 - speak or recite rapidly or in a rolling voice
# 11 None of these.
# >0
# propose to the princess
# PROPOSE
# 0) propose.v.01 - make a proposal, declare a plan for something
# 1) project.v.08 - present for consideration, examination, criticism, etc.
# 2) aim.v.02 - propose or intend
# 3) nominate.v.02 - put forward; nominate for appointment to an office or for an honor or position
# 4) propose.v.05 - ask (someone) to marry you
# 5 None of these.
# >4
# propose to the princess
# PRINCESS
# 0) princess.n.01 - a female member of a royal family other than the queen (especially the daughter of a sovereign)
# 1 None of these.
# >0
# go north
# GO
# 0) go.n.01 - a time for working (after which you will be relieved by someone else)
# 1) adam.n.03 - street names for methylenedioxymethamphetamine
# 2) crack.n.09 - a usually brief attempt
# 3) go.n.04 - a board game for two players who place counters on a grid; the object is to surround and so capture the opponent's counters
# 4) travel.v.01 - change location; move, travel, or proceed, also metaphorically
# 5) go.v.02 - follow a procedure or take a course
# 6) go.v.03 - move away from a place into another direction
# 7) become.v.01 - enter or assume a certain state or condition
# 8) go.v.05 - be awarded; be allotted
# 9) run.v.05 - have a particular form
# 10) run.v.03 - stretch out over a distance, space, time, or scope; run or extend between two points or beyond a certain point
# 11) proceed.v.04 - follow a certain course
# 12) go.v.09 - be abolished or discarded
# 13) go.v.10 - be or continue to be in a certain condition
# 14) sound.v.02 - make a certain noise or sound
# 15) function.v.01 - perform as expected when applied
# 16) run_low.v.01 - to be spent or finished
# 17) move.v.13 - progress by being changed
# 18) survive.v.01 - continue to live through hardship or adversity
# 19) go.v.16 - pass, fare, or elapse; of a certain state of affairs or action
# 20) die.v.01 - pass from physical life and lose all bodily attributes and functions necessary to sustain life
# 21) belong.v.03 - be in the right place or situation
# 22) go.v.19 - be ranked or compare
# 23) start.v.09 - begin or set in motion
# 24) move.v.15 - have a turn; make one's move in a game
# 25) go.v.22 - be contained in
# 26) go.v.23 - be sounded, played, or expressed
# 27) blend.v.02 - blend or harmonize
# 28) go.v.25 - lead, extend, or afford access
# 29) fit.v.02 - be the right size or shape; fit correctly or as desired
# 30) rifle.v.02 - go through in search of something; search through someone's belongings in an unauthorized way
# 31) go.v.28 - be spent
# 32) plump.v.04 - give support (to) or make a choice (of) one out of a group or number
# 33) fail.v.04 - stop operating or functioning
# 34) go.a.01 - functioning correctly and ready for action
# 35 None of these.
# >4
# go north
# NORTH
# 0) north.n.01 - the region of the United States lying to the north of the Mason-Dixon line
# 1) union.n.02 - the United States (especially the northern states during the American Civil War)
# 2) north.n.03 - the cardinal compass point that is at 0 or 360 degrees
# 3) north.n.04 - a location in the northern part of a country, region, or city
# 4) north.n.05 - the direction corresponding to the northward cardinal compass point
# 5) north.n.06 - the direction in which a compass needle points
# 6) north.n.07 - British statesman under George III whose policies led to rebellion in the American colonies (1732-1792)
# 7) north.a.01 - situated in or facing or moving toward or coming from the north
# 8) north.r.01 - in a northern direction
# 9 None of these.
# >2
# First, pick the word sense for the word 'wear'
# ==============
#
# Next, pick which hypernyms of wear.v.09 we should allow players to use.
# ==============
# WEAR
# Is dress.v.01 an appropriate substitute for wear? (y/n)
# It means: put on clothes
# Synonyms are: ['dress', 'get dressed']
# >n
# \Finally, pick which hyponyms of wear.v.09 we should allow players to use.
# ==============
# WEAR
# Is hat.v.01 an appropriate substitute for wear? (y/n)
# It means: put on or wear a hat
# Synonyms are: ['hat']
# >n
# Is scarf.v.03 an appropriate substitute for wear? (y/n)
# It means: wrap in or adorn with a scarf
# Synonyms are: ['scarf']
# >n
# Is slip_on.v.01 an appropriate substitute for wear? (y/n)
# It means: put on with ease or speed
# Synonyms are: ['slip on']
# >y
# Is try_on.v.01 an appropriate substitute for wear? (y/n)
# It means: put on a garment in order to see whether it fits and looks nice
# Synonyms are: ['try on', 'try']
# >y
# First, pick the word sense for the word 'crown'
# ==============
#
# Next, pick which hypernyms of crown.n.03 we should allow players to use.
# ==============
# CROWN
# Is wreath.n.01 an appropriate substitute for crown? (y/n)
# It means: flower arrangement consisting of a circular band of foliage or flowers for ornamental purposes
# Synonyms are: ['wreath', 'garland', 'coronal', 'chaplet', 'lei']
# >n
# \Finally, pick which hyponyms of crown.n.03 we should allow players to use.
# ==============
# CROWN
# Is crown_of_thorns.n.03 an appropriate substitute for crown? (y/n)
# It means: a mock crown made of thorn branches that Roman soldiers placed on Jesus before the Crucifixion
# Synonyms are: ['crown of thorns']
# >n
# First, pick the word sense for the word 'smell'
# ==============
#
# Next, pick which hypernyms of smell.v.01 we should allow players to use.
# ==============
# SMELL
# Is perceive.v.01 an appropriate substitute for smell? (y/n)
# It means: to become aware of through the senses
# Synonyms are: ['perceive', 'comprehend']
# >n
# \Finally, pick which hyponyms of smell.v.01 we should allow players to use.
# ==============
# SMELL
# Is get_a_noseful.v.01 an appropriate substitute for smell? (y/n)
# It means: smell strongly and intensely
# Synonyms are: ['get a noseful', 'get a whiff']
# >y
# Is scent.v.02 an appropriate substitute for smell? (y/n)
# It means: catch the scent of; get wind of
# Synonyms are: ['scent', 'nose', 'wind']
# >n
# Is sniff.v.01 an appropriate substitute for smell? (y/n)
# It means: perceive by inhaling through the nose
# Synonyms are: ['sniff', 'whiff']
# >y
# Is snuff.v.01 an appropriate substitute for smell? (y/n)
# It means: sniff or smell inquiringly
# Synonyms are: ['snuff', 'snuffle']
# >y
# First, pick the word sense for the word 'rose'
# ==============
#
# Next, pick which hypernyms of rose.n.01 we should allow players to use.
# ==============
# ROSE
# Is shrub.n.01 an appropriate substitute for rose? (y/n)
# It means: a low woody perennial plant usually having several major stems
# Synonyms are: ['shrub', 'bush']
# >n
# \Finally, pick which hyponyms of rose.n.01 we should allow players to use.
# ==============
# ROSE
# Is banksia_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: Chinese evergreen climbing rose with yellow or white single flowers
# Synonyms are: ['banksia rose', 'Rosa banksia']
# >n
# Is cherokee_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: Chinese climbing rose with fragrant white blossoms
# Synonyms are: ['Cherokee rose', 'Rosa laevigata']
# >n
# Is china_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: shrubby Chinese rose; ancestor of many cultivated garden roses
# Synonyms are: ['China rose', 'Bengal rose', 'Rosa chinensis']
# >n
# Is damask_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: large hardy very fragrant pink rose; cultivated in Asia Minor as source of attar of roses; parent of many hybrids
# Synonyms are: ['damask rose', 'summer damask rose', 'Rosa damascena']
# >n
# Is dog_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: prickly wild rose with delicate pink or white scentless flowers; native to Europe
# Synonyms are: ['dog rose', 'Rosa canina']
# >n
# Is ground_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: low-growing bristly shrub of southern Oregon and California with creeping rootstocks and usually corymbose flowers
# Synonyms are: ['ground rose', 'Rosa spithamaea']
# >n
# Is mountain_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: European alpine rose with crimson flowers
# Synonyms are: ['mountain rose', 'Rosa pendulina']
# >n
# Is multiflora.n.01 an appropriate substitute for rose? (y/n)
# It means: vigorously growing rose having clusters of numerous small flowers; used for hedges and as grafting stock
# Synonyms are: ['multiflora', 'multiflora rose', 'Japanese rose', 'baby rose', 'Rosa multiflora']
# >n
# Is musk_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: rose native to Mediterranean region having curved or climbing branches and loose clusters of musky-scented flowers
# Synonyms are: ['musk rose', 'Rosa moschata']
# >n
# Is sweetbrier.n.01 an appropriate substitute for rose? (y/n)
# It means: Eurasian rose with prickly stems and fragrant leaves and bright pink flowers followed by scarlet hips
# Synonyms are: ['sweetbrier', 'sweetbriar', 'brier', 'briar', 'eglantine', 'Rosa eglanteria']
# >n
# Is tea_rose.n.01 an appropriate substitute for rose? (y/n)
# It means: any of several hybrid bush roses derived from a tea-scented Chinese rose with pink or yellow flowers
# Synonyms are: ['tea rose', 'Rosa odorata']
# >n
# First, pick the word sense for the word 'eat'
# ==============
#
# Next, pick which hypernyms of eat.v.02 we should allow players to use.
# ==============
# EAT
# Is consume.v.02 an appropriate substitute for eat? (y/n)
# It means: serve oneself to, or consume regularly
# Synonyms are: ['consume', 'ingest', 'take in', 'take', 'have']
# >y
# \Finally, pick which hyponyms of eat.v.02 we should allow players to use.
# ==============
# EAT
# Is break_bread.v.01 an appropriate substitute for eat? (y/n)
# It means: have a meal, usually with company
# Synonyms are: ['break bread']
# >n
# Is breakfast.v.01 an appropriate substitute for eat? (y/n)
# It means: eat an early morning meal
# Synonyms are: ['breakfast']
# >n
# Is brunch.v.01 an appropriate substitute for eat? (y/n)
# It means: eat a meal in the late morning
# Synonyms are: ['brunch']
# >n
# Is dine.v.01 an appropriate substitute for eat? (y/n)
# It means: have supper; eat dinner
# Synonyms are: ['dine']
# >n
# Is eat.v.01 an appropriate substitute for eat? (y/n)
# It means: take in solid food
# Synonyms are: ['eat']
# >y
# Is eat_in.v.01 an appropriate substitute for eat? (y/n)
# It means: eat at home
# Synonyms are: ['eat in', 'dine in']
# >n
# Is eat_out.v.01 an appropriate substitute for eat? (y/n)
# It means: eat at a restaurant or at somebody else's home
# Synonyms are: ['eat out', 'dine out']
# >n
# Is feast.v.01 an appropriate substitute for eat? (y/n)
# It means: partake in a feast or banquet
# Synonyms are: ['feast', 'banquet', 'junket']
# >n
# Is gorge.v.01 an appropriate substitute for eat? (y/n)
# It means: overeat or eat immodestly; make a pig of oneself
# Synonyms are: ['gorge', 'ingurgitate', 'overindulge', 'glut', 'englut', 'stuff', 'engorge', 'overgorge', 'overeat', 'gormandize', 'gormandise', 'gourmandize', 'binge', 'pig out', 'satiate', 'scarf out']
# >n
# Is lunch.v.01 an appropriate substitute for eat? (y/n)
# It means: take the midday meal
# Synonyms are: ['lunch']
# >n
# Is mess.v.01 an appropriate substitute for eat? (y/n)
# It means: eat in a mess hall
# Synonyms are: ['mess']
# >n
# Is nosh.v.01 an appropriate substitute for eat? (y/n)
# It means: eat a snack; eat lightly
# Synonyms are: ['nosh', 'snack']
# >n
# Is picnic.v.01 an appropriate substitute for eat? (y/n)
# It means: eat alfresco, in the open air
# Synonyms are: ['picnic']
# >n
# Is take_out.v.12 an appropriate substitute for eat? (y/n)
# It means: buy and consume food from a restaurant or establishment that sells prepared food
# Synonyms are: ['take out', 'take away']
# >n
# Is victual.v.03 an appropriate substitute for eat? (y/n)
# It means: take in nourishment
# Synonyms are: ['victual']
# >n
# Is devour.v.03 an appropriate substitute for eat? (y/n)
# It means: eat immoderately
# Synonyms are: ['devour', 'down', 'consume', 'go through']
# >y
# Is devour.v.04 an appropriate substitute for eat? (y/n)
# It means: eat greedily
# Synonyms are: ['devour', 'guttle', 'raven', 'pig']
# >n
# Is dunk.v.03 an appropriate substitute for eat? (y/n)
# It means: dip into a liquid while eating
# Synonyms are: ['dunk', 'dip']
# >n
# Is eat_up.v.01 an appropriate substitute for eat? (y/n)
# It means: finish eating all the food on one's plate or on the table
# Synonyms are: ['eat up', 'finish', 'polish off']
# >y
# Is fare.v.02 an appropriate substitute for eat? (y/n)
# It means: eat well
# Synonyms are: ['fare']
# >n
# Is fill_up.v.04 an appropriate substitute for eat? (y/n)
# It means: eat until one is sated
# Synonyms are: ['fill up', 'fill']
# >n
# Is garbage_down.v.01 an appropriate substitute for eat? (y/n)
# It means: eat a large amount of food quickly
# Synonyms are: ['garbage down', 'gobble up', 'shovel in', 'bolt down']
# >y
# Is gluttonize.v.01 an appropriate substitute for eat? (y/n)
# It means: eat a lot and without restraint
# Synonyms are: ['gluttonize', 'gluttonise', 'fress']
# >y
# Is gobble.v.01 an appropriate substitute for eat? (y/n)
# It means: eat hastily without proper chewing
# Synonyms are: ['gobble', 'bolt']
# >y
# Is nibble.v.03 an appropriate substitute for eat? (y/n)
# It means: eat intermittently; take small bites of
# Synonyms are: ['nibble', 'pick', 'piece']
# >n
# Is peck.v.02 an appropriate substitute for eat? (y/n)
# It means: eat by pecking at, like a bird
# Synonyms are: ['peck', 'pick up']
# >n
# Is pick_at.v.02 an appropriate substitute for eat? (y/n)
# It means: eat like a bird
# Synonyms are: ['pick at', 'peck at', 'peck']
# >n
# Is pitch_in.v.01 an appropriate substitute for eat? (y/n)
# It means: eat heartily
# Synonyms are: ['pitch in', 'dig in']
# >n
# Is ruminate.v.01 an appropriate substitute for eat? (y/n)
# It means: chew the cuds
# Synonyms are: ['ruminate']
# >n
# Is slurp.v.01 an appropriate substitute for eat? (y/n)
# It means: eat noisily
# Synonyms are: ['slurp']
# >y
# Is wash_down.v.01 an appropriate substitute for eat? (y/n)
# It means: eat food accompanied by lots of liquid; also use metaphorically
# Synonyms are: ['wash down']
# >y
# Is wolf.v.01 an appropriate substitute for eat? (y/n)
# It means: eat hastily
# Synonyms are: ['wolf', 'wolf down']
# >y
# Is tuck_in.v.01 an appropriate substitute for eat? (y/n)
# It means: eat up; usually refers to a considerable quantity of food
# Synonyms are: ['tuck in', 'tuck away', 'put away']
# >n
# First, pick the word sense for the word 'fish'
# ==============
#
# Next, pick which hypernyms of fish.n.01 we should allow players to use.
# ==============
# FISH
# Is aquatic_vertebrate.n.01 an appropriate substitute for fish? (y/n)
# It means: animal living wholly or chiefly in or on water
# Synonyms are: ['aquatic vertebrate']
# >y
# Is vertebrate.n.01 an appropriate substitute for fish? (y/n)
# It means: animals having a bony or cartilaginous skeleton with a segmented spinal column and a large brain enclosed in a skull or cranium
# Synonyms are: ['vertebrate', 'craniate']
# >n
# \Finally, pick which hyponyms of fish.n.01 we should allow players to use.
# ==============
# FISH
# Is bony_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish of the class Osteichthyes
# Synonyms are: ['bony fish']
# >y
# Is bottom-feeder.n.02 an appropriate substitute for fish? (y/n)
# It means: a fish that lives and feeds on the bottom of a body of water
# Synonyms are: ['bottom-feeder', 'bottom-dweller']
# >y
# Is bottom_lurkers.n.01 an appropriate substitute for fish? (y/n)
# It means: a fish that lurks on the bottom of a body of water
# Synonyms are: ['bottom lurkers']
# >n
# Is cartilaginous_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: fishes in which the skeleton may be calcified but not ossified
# Synonyms are: ['cartilaginous fish', 'chondrichthian']
# >y
# Is climbing_perch.n.01 an appropriate substitute for fish? (y/n)
# It means: a small perch of India whose gills are modified to allow it to breathe air; has spiny pectoral fins that enable it to travel on land
# Synonyms are: ['climbing perch', 'Anabas testudineus', 'A. testudineus']
# >n
# Is fingerling.n.01 an appropriate substitute for fish? (y/n)
# It means: a young or small fish
# Synonyms are: ['fingerling']
# >n
# Is food_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish used for food by human beings
# Synonyms are: ['food fish']
# >y
# Is game_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish providing sport for the angler
# Synonyms are: ['game fish', 'sport fish']
# >y
# Is mouthbreeder.n.01 an appropriate substitute for fish? (y/n)
# It means: any of various fishes that carry their eggs and their young in their mouths
# Synonyms are: ['mouthbreeder']
# >n
# Is northern_snakehead.n.01 an appropriate substitute for fish? (y/n)
# It means: a voracious freshwater fish that is native to northeastern China; can use fin to walk and can survive out of water for three days; a threat to American populations of fish
# Synonyms are: ['northern snakehead']
# >n
# Is rough_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish useless for food or sport or even as bait
# Synonyms are: ['rough fish']
# >n
# Is spawner.n.01 an appropriate substitute for fish? (y/n)
# It means: a female fish at spawning time
# Synonyms are: ['spawner']
# >n
# Is young_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: a fish that is young
# Synonyms are: ['young fish']
# >n
# Is crossopterygian.n.01 an appropriate substitute for fish? (y/n)
# It means: any fish of the order Crossopterygii; most known only in fossil form
# Synonyms are: ['crossopterygian', 'lobefin', 'lobe-finned fish']
# >n
# Is lungfish.n.01 an appropriate substitute for fish? (y/n)
# It means: air-breathing fish having an elongated body and fleshy paired fins; certain species construct mucus-lined mud coverings in which to survive drought
# Synonyms are: ['lungfish']
# >n
# Is teleost_fish.n.01 an appropriate substitute for fish? (y/n)
# It means: a bony fish of the subclass Teleostei
# Synonyms are: ['teleost fish', 'teleost', 'teleostan']
# >n
# Is mullet.n.03 an appropriate substitute for fish? (y/n)
# It means: bottom dwelling marine warm water fishes with two barbels on the chin
# Synonyms are: ['mullet']
# >n
# Is elasmobranch.n.01 an appropriate substitute for fish? (y/n)
# It means: any of numerous fishes of the class Chondrichthyes characterized by a cartilaginous skeleton and placoid scales: sharks; rays; skates
# Synonyms are: ['elasmobranch', 'selachian']
# >n
# Is holocephalan.n.01 an appropriate substitute for fish? (y/n)
# It means: fish with high compressed head and a body tapering off into a long tail
# Synonyms are: ['holocephalan', 'holocephalian']
# >n
# Is barracouta.n.01 an appropriate substitute for fish? (y/n)
# It means: a large marine food fish common on the coasts of Australia, New Zealand, and southern Africa
# Synonyms are: ['barracouta', 'snoek']
# >n
# Is groundfish.n.01 an appropriate substitute for fish? (y/n)
# It means: fish that live on the sea bottom (particularly the commercially important gadoid fish like cod and haddock, or flatfish like flounder)
# Synonyms are: ['groundfish', 'bottom fish']
# >n
# Is herring.n.02 an appropriate substitute for fish? (y/n)
# It means: commercially important food fish of northern waters of both Atlantic and Pacific
# Synonyms are: ['herring', 'Clupea harangus']
# >n
# Is salmon.n.01 an appropriate substitute for fish? (y/n)
# It means: any of various large food and game fishes of northern waters; usually migrate from salt to fresh water to spawn
# Synonyms are: ['salmon']
# >n
# Is sardine.n.02 an appropriate substitute for fish? (y/n)
# It means: any of various small edible herring or related food fishes frequently canned
# Synonyms are: ['sardine']
# >n
# Is sea_bass.n.02 an appropriate substitute for fish? (y/n)
# It means: any of various food and sport fishes of the Atlantic coast of the United States having an elongated body and long spiny dorsal fin
# Synonyms are: ['sea bass']
# >n
# Is shad.n.02 an appropriate substitute for fish? (y/n)
# It means: herring-like food fishes that migrate from the sea to fresh water to spawn
# Synonyms are: ['shad']
# >n
# Is snapper.n.05 an appropriate substitute for fish? (y/n)
# It means: any of several large sharp-toothed marine food and sport fishes of the family Lutjanidae of mainly tropical coastal waters
# Synonyms are: ['snapper']
# >n
# Is sole.n.04 an appropriate substitute for fish? (y/n)
# It means: right-eyed flatfish; many are valued as food; most common in warm seas especially European
# Synonyms are: ['sole']
# >n
# Is trout.n.02 an appropriate substitute for fish? (y/n)
# It means: any of various game and food fishes of cool fresh waters mostly smaller than typical salmons
# Synonyms are: ['trout']
# >n
# Is tuna.n.03 an appropriate substitute for fish? (y/n)
# It means: any very large marine food and game fish of the genus Thunnus; related to mackerel; chiefly of warm waters
# Synonyms are: ['tuna', 'tunny']
# >n
# Is whitefish.n.03 an appropriate substitute for fish? (y/n)
# It means: silvery herring-like freshwater food fish of cold lakes of the northern hemisphere
# Synonyms are: ['whitefish']
# >n
# First, pick the word sense for the word 'light'
# ==============
#
# Next, pick which hypernyms of ignite.v.01 we should allow players to use.
# ==============
# LIGHT
# Is burn.v.05 an appropriate substitute for light? (y/n)
# It means: cause to burn or combust
# Synonyms are: ['burn', 'combust']
# >y
# \Finally, pick which hyponyms of ignite.v.01 we should allow players to use.
# ==============
# LIGHT
# Is flare_up.v.01 an appropriate substitute for light? (y/n)
# It means: ignite quickly and suddenly, especially after having died down
# Synonyms are: ['flare up']
# >y
# Is kindle.v.02 an appropriate substitute for light? (y/n)
# It means: cause to start burning
# Synonyms are: ['kindle', 'enkindle', 'conflagrate', 'inflame']
# >y
# Is light_up.v.04 an appropriate substitute for light? (y/n)
# It means: ignite
# Synonyms are: ['light up']
# >y
# Is light_up.v.05 an appropriate substitute for light? (y/n)
# It means: begin to smoke
# Synonyms are: ['light up', 'fire up', 'light']
# >y
# Is reignite.v.01 an appropriate substitute for light? (y/n)
# It means: ignite anew, as of something burning
# Synonyms are: ['reignite']
# >y
# Is kindle.v.01 an appropriate substitute for light? (y/n)
# It means: catch fire
# Synonyms are: ['kindle', 'inflame']
# >y
# Is rekindle.v.01 an appropriate substitute for light? (y/n)
# It means: kindle anew, as of a fire
# Synonyms are: ['rekindle']
# >y
# First, pick the word sense for the word 'lamp'
# ==============
#
# Next, pick which hypernyms of lamp.n.01 we should allow players to use.
# ==============
# LAMP
# Is source_of_illumination.n.01 an appropriate substitute for lamp? (y/n)
# It means: any device serving as a source of visible electromagnetic radiation
# Synonyms are: ['source of illumination']
# >y
# Is device.n.01 an appropriate substitute for lamp? (y/n)
# It means: an instrumentality invented for a particular purpose
# Synonyms are: ['device']
# >n
# \Finally, pick which hyponyms of lamp.n.01 we should allow players to use.
# ==============
# LAMP
# Is aladdin's_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: (Arabian Nights) a magical lamp from which Aladdin summoned a genie
# Synonyms are: ["Aladdin's lamp"]
# >n
# Is candle.n.01 an appropriate substitute for lamp? (y/n)
# It means: stick of wax with a wick in the middle
# Synonyms are: ['candle', 'taper', 'wax light']
# >n
# Is discharge_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp that generates light by a discharge between two electrodes in a gas
# Synonyms are: ['discharge lamp']
# >n
# Is electric_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp powered by electricity
# Synonyms are: ['electric lamp']
# >n
# Is flash.n.10 an appropriate substitute for lamp? (y/n)
# It means: a lamp for providing momentary light to take a photograph
# Synonyms are: ['flash', 'photoflash', 'flash lamp', 'flashgun', 'flashbulb', 'flash bulb']
# >n
# Is fluorescent_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: lamp consisting of a tube coated on the inside with a fluorescent material; mercury vapor in the tube emits ultraviolet radiation that is converted to visible radiation by the fluorescent material
# Synonyms are: ['fluorescent lamp']
# >n
# Is gas_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp that burns illuminating gas
# Synonyms are: ['gas lamp']
# >n
# Is hurricane_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: an oil lamp with a glass chimney and perforated metal lid to protect the flame from high winds; candlestick with a glass chimney
# Synonyms are: ['hurricane lamp', 'hurricane lantern', 'tornado lantern', 'storm lantern', 'storm lamp']
# >n
# Is lantern.n.01 an appropriate substitute for lamp? (y/n)
# It means: light in a transparent protective case
# Synonyms are: ['lantern']
# >y
# Is limelight.n.02 an appropriate substitute for lamp? (y/n)
# It means: a lamp consisting of a flame directed at a cylinder of lime with a lens to concentrate the light; formerly used for stage lighting
# Synonyms are: ['limelight', 'calcium light']
# >n
# Is neon_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp consisting of a small gas-discharge tube containing neon at low pressure; luminescence is produced by the action of currents at high frequencies that are wrapped a few turns around the tube
# Synonyms are: ['neon lamp', 'neon induction lamp', 'neon tube']
# >n
# Is oil_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp that burns oil (as kerosine) for light
# Synonyms are: ['oil lamp', 'kerosene lamp', 'kerosine lamp']
# >n
# Is sodium-vapor_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: lamp in which an electric current passed through a tube of sodium vapor makes a yellow light; used is street lighting
# Synonyms are: ['sodium-vapor lamp', 'sodium-vapour lamp']
# >n
# Is spirit_lamp.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp that burns a volatile liquid fuel such as alcohol
# Synonyms are: ['spirit lamp']
# >n
# Is spotlight.n.02 an appropriate substitute for lamp? (y/n)
# It means: a lamp that produces a strong beam of light to illuminate a restricted area; used to focus attention of a stage performer
# Synonyms are: ['spotlight', 'spot']
# >n
# Is streetlight.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lamp supported on a lamppost; for illuminating a street
# Synonyms are: ['streetlight', 'street lamp']
# >n
# Is taillight.n.01 an appropriate substitute for lamp? (y/n)
# It means: lamp (usually red) mounted at the rear of a motor vehicle
# Synonyms are: ['taillight', 'tail lamp', 'rear light', 'rear lamp']
# >n
# Is chinese_lantern.n.01 an appropriate substitute for lamp? (y/n)
# It means: a collapsible paper lantern in bright colors; used for decorative purposes
# Synonyms are: ['Chinese lantern']
# >n
# Is dark_lantern.n.01 an appropriate substitute for lamp? (y/n)
# It means: a lantern with a single opening and a sliding panel that can be closed to conceal the light
# Synonyms are: ['dark lantern', "bull's-eye"]
# >n
# Is jack-o'-lantern.n.02 an appropriate substitute for lamp? (y/n)
# It means: lantern carved from a pumpkin
# Synonyms are: ["jack-o'-lantern"]
# >n
# First, pick the word sense for the word 'give'
# ==============
#
# Next, pick which hypernyms of give.v.03 we should allow players to use.
# ==============
# GIVE
# Is transfer.v.05 an appropriate substitute for give? (y/n)
# It means: cause to change ownership
# Synonyms are: ['transfer']
# >y
# \Finally, pick which hyponyms of give.v.03 we should allow players to use.
# ==============
# GIVE
# Is accord.v.02 an appropriate substitute for give? (y/n)
# It means: allow to have
# Synonyms are: ['accord', 'allot', 'grant']
# >y
# Is allow.v.03 an appropriate substitute for give? (y/n)
# It means: let have
# Synonyms are: ['allow', 'grant']
# >y
# Is bestow.v.02 an appropriate substitute for give? (y/n)
# It means: give as a gift
# Synonyms are: ['bestow']
# >y
# Is concede.v.03 an appropriate substitute for give? (y/n)
# It means: give over; surrender or relinquish to the physical control of another
# Synonyms are: ['concede', 'yield', 'cede', 'grant']
# >y
# Is contribute.v.02 an appropriate substitute for give? (y/n)
# It means: contribute to some cause
# Synonyms are: ['contribute', 'give', 'chip in', 'kick in']
# >y
# Is cough_up.v.01 an appropriate substitute for give? (y/n)
# It means: give reluctantly
# Synonyms are: ['cough up', 'pony up', 'spit up']
# >y
# Is deposit.v.02 an appropriate substitute for give? (y/n)
# It means: put into a bank account
# Synonyms are: ['deposit', 'bank']
# >n
# Is distribute.v.01 an appropriate substitute for give? (y/n)
# It means: administer or bestow, as in small portions
# Synonyms are: ['distribute', 'administer', 'mete out', 'deal', 'parcel out', 'lot', 'dispense', 'shell out', 'deal out', 'dish out', 'allot', 'dole out']
# >y
# Is enfeoff.v.01 an appropriate substitute for give? (y/n)
# It means: put in possession of land in exchange for a pledge of service, in feudal society
# Synonyms are: ['enfeoff']
# >n
# Is heap.v.01 an appropriate substitute for give? (y/n)
# It means: bestow in large quantities
# Synonyms are: ['heap']
# >n
# Is lease.v.03 an appropriate substitute for give? (y/n)
# It means: grant use or occupation of under a term of contract
# Synonyms are: ['lease', 'let', 'rent']
# >n
# Is lend.v.02 an appropriate substitute for give? (y/n)
# It means: give temporarily; let have for a limited time
# Synonyms are: ['lend', 'loan']
# >y
# Is offer.v.02 an appropriate substitute for give? (y/n)
# It means: present for acceptance or rejection
# Synonyms are: ['offer', 'proffer']
# >y
# Is pay.v.01 an appropriate substitute for give? (y/n)
# It means: give money, usually in exchange for goods or services
# Synonyms are: ['pay']
# >n
# Is present.v.04 an appropriate substitute for give? (y/n)
# It means: hand over formally
# Synonyms are: ['present', 'submit']
# >y
# Is provide.v.02 an appropriate substitute for give? (y/n)
# It means: give what is desired or needed, especially support, food or sustenance
# Synonyms are: ['provide', 'supply', 'ply', 'cater']
# >y
# Is render.v.07 an appropriate substitute for give? (y/n)
# It means: give back
# Synonyms are: ['render', 'return']
# >n
# Is requite.v.01 an appropriate substitute for give? (y/n)
# It means: make repayment for or return something
# Synonyms are: ['requite', 'repay']
# >n
# Is spare.v.03 an appropriate substitute for give? (y/n)
# It means: give up what is not strictly needed
# Synonyms are: ['spare', 'give up', 'part with', 'dispense with']
# >n
# Is supply.v.01 an appropriate substitute for give? (y/n)
# It means: give something useful or necessary to
# Synonyms are: ['supply', 'provide', 'render', 'furnish']
# >y
# Is support.v.02 an appropriate substitute for give? (y/n)
# It means: support materially or financially
# Synonyms are: ['support']
# >n
# Is vest.v.02 an appropriate substitute for give? (y/n)
# It means: place (authority, property, or rights) in the control of a person or group of persons
# Synonyms are: ['vest']
# >y
# Is enfranchise.v.02 an appropriate substitute for give? (y/n)
# It means: grant voting rights
# Synonyms are: ['enfranchise']
# >n
# Is give.v.35 an appropriate substitute for give? (y/n)
# It means: accord by verdict
# Synonyms are: ['give']
# >y
# Is allowance.v.01 an appropriate substitute for give? (y/n)
# It means: put on a fixed allowance, as of food
# Synonyms are: ['allowance']
# >n
# Is vouchsafe.v.01 an appropriate substitute for give? (y/n)
# It means: grant in a condescending manner
# Synonyms are: ['vouchsafe']
# >n
# Is combine.v.04 an appropriate substitute for give? (y/n)
# It means: add together from different sources
# Synonyms are: ['combine']
# >n
# Is assign.v.02 an appropriate substitute for give? (y/n)
# It means: give out
# Synonyms are: ['assign', 'allot', 'portion']
# >y
# Is deal.v.09 an appropriate substitute for give? (y/n)
# It means: distribute cards to the players in a game
# Synonyms are: ['deal']
# >n
# Is give.v.20 an appropriate substitute for give? (y/n)
# It means: give or convey physically
# Synonyms are: ['give', 'apply']
# >y
# Is reallot.v.01 an appropriate substitute for give? (y/n)
# It means: allot again
# Synonyms are: ['reallot']
# >y
# Is advance.v.10 an appropriate substitute for give? (y/n)
# It means: pay in advance
# Synonyms are: ['advance']
# >n
# Is hire_out.v.01 an appropriate substitute for give? (y/n)
# It means: grant the services of or the temporary use of, for a fee
# Synonyms are: ['hire out', 'rent out', 'farm out']
# >n
# Is trust.v.06 an appropriate substitute for give? (y/n)
# It means: extend credit to; I won't pay her debts anymore"
# Synonyms are: ['trust']
# >n
# Is give.v.44 an appropriate substitute for give? (y/n)
# It means: proffer (a body part)
# Synonyms are: ['give']
# >n
# Is tender.v.03 an appropriate substitute for give? (y/n)
# It means: make a tender of; in legal settlements
# Synonyms are: ['tender']
# >n
# Is bring_in.v.04 an appropriate substitute for give? (y/n)
# It means: submit (a verdict) to a court
# Synonyms are: ['bring in']
# >n
# Is accommodate.v.03 an appropriate substitute for give? (y/n)
# It means: provide with something desired or needed
# Synonyms are: ['accommodate']
# >n
# Is board.v.04 an appropriate substitute for give? (y/n)
# It means: provide food and lodging (for)
# Synonyms are: ['board']
# >n
# Is cater.v.02 an appropriate substitute for give? (y/n)
# It means: supply food ready to eat; for parties and banquets
# Synonyms are: ['cater']
# >y
# Is drench.v.02 an appropriate substitute for give? (y/n)
# It means: force to drink
# Synonyms are: ['drench']
# >n
# Is feed.v.01 an appropriate substitute for give? (y/n)
# It means: provide as food
# Synonyms are: ['feed']
# >y
# Is feed.v.02 an appropriate substitute for give? (y/n)
# It means: give food to
# Synonyms are: ['feed', 'give']
# >y
# Is feed.v.07 an appropriate substitute for give? (y/n)
# It means: serve as food for; be the food for
# Synonyms are: ['feed']
# >y
# Is fix_up.v.01 an appropriate substitute for give? (y/n)
# It means: find (something or someone) for
# Synonyms are: ['fix up']
# >n
# Is gratify.v.02 an appropriate substitute for give? (y/n)
# It means: yield (to); give satisfaction to
# Synonyms are: ['gratify', 'pander', 'indulge']
# >n
# Is gutter.v.04 an appropriate substitute for give? (y/n)
# It means: provide with gutters
# Synonyms are: ['gutter']
# >n
# Is horse.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a horse or horses
# Synonyms are: ['horse']
# >n
# Is meet.v.04 an appropriate substitute for give? (y/n)
# It means: fill or meet a want or need
# Synonyms are: ['meet', 'satisfy', 'fill', 'fulfill', 'fulfil']
# >n
# Is nourish.v.01 an appropriate substitute for give? (y/n)
# It means: provide with nourishment
# Synonyms are: ['nourish', 'nurture', 'sustain']
# >n
# Is pander.v.02 an appropriate substitute for give? (y/n)
# It means: arrange for sexual partners for others
# Synonyms are: ['pander', 'pimp', 'procure']
# >n
# Is power.v.01 an appropriate substitute for give? (y/n)
# It means: supply the force or power for the functioning of
# Synonyms are: ['power']
# >n
# Is regale.v.01 an appropriate substitute for give? (y/n)
# It means: provide with choice or abundant food or drink
# Synonyms are: ['regale', 'treat']
# >n
# Is serve.v.05 an appropriate substitute for give? (y/n)
# It means: help to some food; help with food or drink
# Synonyms are: ['serve', 'help']
# >n
# Is serve.v.06 an appropriate substitute for give? (y/n)
# It means: provide (usually but not necessarily food)
# Synonyms are: ['serve', 'serve up', 'dish out', 'dish up', 'dish']
# >y
# Is shower.v.05 an appropriate substitute for give? (y/n)
# It means: provide abundantly with
# Synonyms are: ['shower']
# >n
# Is staff.v.01 an appropriate substitute for give? (y/n)
# It means: provide with staff
# Synonyms are: ['staff']
# >n
# Is underlay.v.03 an appropriate substitute for give? (y/n)
# It means: provide with a base, support, lining, or backing
# Synonyms are: ['underlay']
# >n
# Is air-cool.v.01 an appropriate substitute for give? (y/n)
# It means: equip with an apparatus for controlling the humidity and temperature
# Synonyms are: ['air-cool', 'air-condition']
# >n
# Is alphabetize.v.02 an appropriate substitute for give? (y/n)
# It means: provide with an alphabet
# Synonyms are: ['alphabetize']
# >n
# Is arm.v.02 an appropriate substitute for give? (y/n)
# It means: supply with arms
# Synonyms are: ['arm']
# >n
# Is bed.v.01 an appropriate substitute for give? (y/n)
# It means: furnish with a bed
# Synonyms are: ['bed']
# >n
# Is berth.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a berth
# Synonyms are: ['berth']
# >n
# Is bewhisker.v.01 an appropriate substitute for give? (y/n)
# It means: furnish with whiskers
# Synonyms are: ['bewhisker', 'whisker']
# >n
# Is border.v.04 an appropriate substitute for give? (y/n)
# It means: provide with a border or edge
# Synonyms are: ['border', 'edge']
# >n
# Is bottom.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a bottom or a seat
# Synonyms are: ['bottom']
# >n
# Is brattice.v.01 an appropriate substitute for give? (y/n)
# It means: supply with a brattice, to ventilate mines
# Synonyms are: ['brattice']
# >n
# Is bush.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a bushing
# Synonyms are: ['bush']
# >n
# Is calk.v.01 an appropriate substitute for give? (y/n)
# It means: provide with calks
# Synonyms are: ['calk']
# >n
# Is canal.v.01 an appropriate substitute for give? (y/n)
# It means: provide (a city) with a canal
# Synonyms are: ['canal', 'canalize', 'canalise']
# >n
# Is capitalize.v.02 an appropriate substitute for give? (y/n)
# It means: supply with capital, as of a business by using a combination of capital used by investors and debt capital provided by lenders
# Synonyms are: ['capitalize', 'capitalise']
# >n
# Is caption.v.01 an appropriate substitute for give? (y/n)
# It means: provide with a caption, as of a photograph or a drawing
# Synonyms are: ['caption']
# >n
# ...
# It means: move effortlessly; by force of gravity
# Synonyms are: ['coast']
# >y
# Is plane.v.02 an appropriate substitute for go? (y/n)
# It means: travel on the surface of water
# Synonyms are: ['plane', 'skim']
# >n
# Is skate.v.01 an appropriate substitute for go? (y/n)
# It means: move along on skates
# Synonyms are: ['skate']
# >n
# Is skid.v.04 an appropriate substitute for go? (y/n)
# It means: move obliquely or sideways, usually in an uncontrolled manner
# Synonyms are: ['skid', 'slip', 'slue', 'slew', 'slide']
# >y
# Is skitter.v.02 an appropriate substitute for go? (y/n)
# It means: glide easily along a surface
# Synonyms are: ['skitter']
# >y
# Is snake.v.01 an appropriate substitute for go? (y/n)
# It means: move smoothly and sinuously, like a snake
# Synonyms are: ['snake']
# >y
# Is snowboard.v.01 an appropriate substitute for go? (y/n)
# It means: glide down a snow-covered slope while standing on a board
# Synonyms are: ['snowboard']
# >n
# Is surfboard.v.01 an appropriate substitute for go? (y/n)
# It means: ride the waves of the sea with a surfboard
# Synonyms are: ['surfboard', 'surf']
# >n
# Is canter.v.02 an appropriate substitute for go? (y/n)
# It means: go at a canter, of horses
# Synonyms are: ['canter']
# >n
# Is gallop.v.02 an appropriate substitute for go? (y/n)
# It means: go at galloping speed
# Synonyms are: ['gallop']
# >y
# Is single-foot.v.01 an appropriate substitute for go? (y/n)
# It means: go at a rack
# Synonyms are: ['single-foot', 'rack']
# >n
# Is walk.v.08 an appropriate substitute for go? (y/n)
# It means: walk at a pace
# Synonyms are: ['walk']
# >y
# Is head.v.01 an appropriate substitute for go? (y/n)
# It means: to go or travel towards
# Synonyms are: ['head']
# >y
# Is limp.v.02 an appropriate substitute for go? (y/n)
# It means: proceed slowly or with difficulty
# Synonyms are: ['limp']
# >y
# Is roar.v.04 an appropriate substitute for go? (y/n)
# It means: act or proceed in a riotous, turbulent, or disorderly way
# Synonyms are: ['roar']
# >n
# Is trace.v.06 an appropriate substitute for go? (y/n)
# It means: make one's course or travel along a path; travel or pass over, around, or along
# Synonyms are: ['trace']
# >n
# Is wander.v.03 an appropriate substitute for go? (y/n)
# It means: go via an indirect route or at no set pace
# Synonyms are: ['wander']
# >y
# Is chase.v.01 an appropriate substitute for go? (y/n)
# It means: go after with the intent to catch
# Synonyms are: ['chase', 'chase after', 'trail', 'tail', 'tag', 'give chase', 'dog', 'go after', 'track']
# >n
# Is haunt.v.01 an appropriate substitute for go? (y/n)
# It means: follow stealthily or recur constantly and spontaneously to
# Synonyms are: ['haunt', 'stalk']
# >y
# Is stalk.v.03 an appropriate substitute for go? (y/n)
# It means: go through (an area) in search of prey
# Synonyms are: ['stalk']
# >y
# Is cocoon.v.01 an appropriate substitute for go? (y/n)
# It means: retreat as if into a cocoon, as from an unfriendly environment
# Synonyms are: ['cocoon']
# >n
# Is gallivant.v.01 an appropriate substitute for go? (y/n)
# It means: wander aimlessly in search of pleasure
# Synonyms are: ['gallivant', 'gad', 'jazz around']
# >y
# Is maunder.v.01 an appropriate substitute for go? (y/n)
# It means: wander aimlessly
# Synonyms are: ['maunder']
# >y
# Is barge.v.01 an appropriate substitute for go? (y/n)
# It means: push one's way
# Synonyms are: ['barge', 'thrust ahead', 'push forward']
# >n
# Is dart.v.02 an appropriate substitute for go? (y/n)
# It means: run or move very quickly or hastily
# Synonyms are: ['dart', 'dash', 'scoot', 'scud', 'flash', 'shoot']
# >n
# Is tear.v.03 an appropriate substitute for go? (y/n)
# It means: move quickly and violently
# Synonyms are: ['tear', 'shoot', 'shoot down', 'charge', 'buck']
# >y
# Is cruise.v.01 an appropriate substitute for go? (y/n)
# It means: drive around aimlessly but ostentatiously and at leisure
# Synonyms are: ['cruise']
# >y
# Is fly.v.12 an appropriate substitute for go? (y/n)
# It means: travel over (an area of land or sea) in an aircraft
# Synonyms are: ['fly']
# >n
# Is ride.v.12 an appropriate substitute for go? (y/n)
# It means: ride over, along, or through
# Synonyms are: ['ride']
# >n
# Is sail.v.01 an appropriate substitute for go? (y/n)
# It means: traverse or travel on (a body of water)
# Synonyms are: ['sail']
# >n
# Is ship.v.04 an appropriate substitute for go? (y/n)
# It means: travel by ship
# Synonyms are: ['ship']
# >n
# Is flit.v.01 an appropriate substitute for go? (y/n)
# It means: move along rapidly and lightly; skim or dart
# Synonyms are: ['flit', 'flutter', 'fleet', 'dart']
# >y
# Is run.v.01 an appropriate substitute for go? (y/n)
# It means: move fast by using one's feet, with one foot off the ground at any given time
# Synonyms are: ['run']
# >y
# Is zoom.v.01 an appropriate substitute for go? (y/n)
# It means: move along very quickly
# Synonyms are: ['zoom', 'zoom along', 'whizz', 'whizz along']
# >y
# Is amble.v.01 an appropriate substitute for go? (y/n)
# It means: walk leisurely
# Synonyms are: ['amble', 'mosey']
# >y
# Is ambulate.v.01 an appropriate substitute for go? (y/n)
# It means: walk about; not be bedridden or incapable of walking
# Synonyms are: ['ambulate']
# >y
# Is clump.v.03 an appropriate substitute for go? (y/n)
# It means: walk clumsily
# Synonyms are: ['clump', 'clomp']
# >y
# Is flounce.v.01 an appropriate substitute for go? (y/n)
# It means: walk emphatically
# Synonyms are: ['flounce']
# >y
# Is foot.v.02 an appropriate substitute for go? (y/n)
# It means: walk
# Synonyms are: ['foot', 'leg it', 'hoof', 'hoof it']
# >n
# Is hike.v.02 an appropriate substitute for go? (y/n)
# It means: walk a long way, as for pleasure or physical exercise
# Synonyms are: ['hike']
# >y
# Is limp.v.01 an appropriate substitute for go? (y/n)
# It means: walk impeded by some physical limitation or injury
# Synonyms are: ['limp', 'gimp', 'hobble', 'hitch']
# >n
# Is lollop.v.01 an appropriate substitute for go? (y/n)
# It means: walk clumsily and with a bounce
# Synonyms are: ['lollop']
# >y
# Is lumber.v.01 an appropriate substitute for go? (y/n)
# It means: move heavily or clumsily
# Synonyms are: ['lumber', 'pound']
# >y
# Is march.v.01 an appropriate substitute for go? (y/n)
# It means: march in a procession
# Synonyms are: ['march', 'process']
# >y
# Is march.v.03 an appropriate substitute for go? (y/n)
# It means: walk fast, with regular or measured steps; walk with a stride
# Synonyms are: ['march']
# >y
# Is mince.v.02 an appropriate substitute for go? (y/n)
# It means: walk daintily
# Synonyms are: ['mince']
# >y
# Is pace.v.01 an appropriate substitute for go? (y/n)
# It means: walk with slow or fast paces
# Synonyms are: ['pace']
# >y
# Is perambulate.v.02 an appropriate substitute for go? (y/n)
# It means: walk with no particular goal
# Synonyms are: ['perambulate', 'walk about', 'walk around']
# >n
# Is promenade.v.02 an appropriate substitute for go? (y/n)
# It means: take a leisurely walk
# Synonyms are: ['promenade']
# >y
# Is prowl.v.01 an appropriate substitute for go? (y/n)
# It means: move about in or as if in a predatory manner
# Synonyms are: ['prowl']
# >y
# Is shuffle.v.01 an appropriate substitute for go? (y/n)
# It means: walk by dragging one's feet
# Synonyms are: ['shuffle', 'scuffle', 'shamble']
# >y
# Is skulk.v.03 an appropriate substitute for go? (y/n)
# It means: move stealthily
# Synonyms are: ['skulk']
# >y
# Is sleepwalk.v.01 an appropriate substitute for go? (y/n)
# It means: walk in one's sleep
# Synonyms are: ['sleepwalk', 'somnambulate']
# >n
# Is slink.v.01 an appropriate substitute for go? (y/n)
# It means: walk stealthily
# Synonyms are: ['slink']
# >y
# Is slog.v.02 an appropriate substitute for go? (y/n)
# It means: walk heavily and firmly, as when weary, or through mud
# Synonyms are: ['slog', 'footslog', 'plod', 'trudge', 'pad', 'tramp']
# >y
# Is slouch.v.02 an appropriate substitute for go? (y/n)
# It means: walk slovenly
# Synonyms are: ['slouch']
# >y
# Is sneak.v.01 an appropriate substitute for go? (y/n)
# It means: to go stealthily or furtively
# Synonyms are: ['sneak', 'mouse', 'creep', 'pussyfoot']
# >y
# Is spacewalk.v.01 an appropriate substitute for go? (y/n)
# It means: move in space outside a space craft
# Synonyms are: ['spacewalk']
# >n
# Is stagger.v.01 an appropriate substitute for go? (y/n)
# It means: walk as if unable to control one's movements
# Synonyms are: ['stagger', 'reel', 'keel', 'lurch', 'swag', 'careen']
# >y
# Is stagger.v.02 an appropriate substitute for go? (y/n)
# It means: walk with great difficulty
# Synonyms are: ['stagger', 'flounder']
# >y
# Is stalk.v.01 an appropriate substitute for go? (y/n)
# It means: walk stiffly
# Synonyms are: ['stalk']
# >n
# Is step.v.07 an appropriate substitute for go? (y/n)
# It means: walk a short distance to a specified place or in a specified manner
# Synonyms are: ['step']
# >y
# Is stomp.v.01 an appropriate substitute for go? (y/n)
# It means: walk heavily
# Synonyms are: ['stomp', 'stamp', 'stump']
# >y
# Is stride.v.01 an appropriate substitute for go? (y/n)
# It means: walk with long steps
# Synonyms are: ['stride']
# >y
# Is stroll.v.01 an appropriate substitute for go? (y/n)
# It means: walk leisurely and with no apparent aim
# Synonyms are: ['stroll', 'saunter']
# >y
# Is stumble.v.01 an appropriate substitute for go? (y/n)
# It means: walk unsteadily
# Synonyms are: ['stumble', 'falter', 'bumble']
# >y
# Is tap.v.08 an appropriate substitute for go? (y/n)
# It means: walk with a tapping sound
# Synonyms are: ['tap']
# >y
# Is tiptoe.v.01 an appropriate substitute for go? (y/n)
# It means: walk on one's toes
# Synonyms are: ['tiptoe', 'tip', 'tippytoe']
# >y
# Is tittup.v.01 an appropriate substitute for go? (y/n)
# It means: to walk with a lofty proud gait, often in an attempt to impress others
# Synonyms are: ['tittup', 'swagger', 'ruffle', 'prance', 'strut', 'sashay', 'cock']
# >y
# Is toddle.v.01 an appropriate substitute for go? (y/n)
# It means: walk unsteadily
# Synonyms are: ['toddle', 'coggle', 'totter', 'dodder', 'paddle', 'waddle']
# >y
# Is toe.v.01 an appropriate substitute for go? (y/n)
# It means: walk so that the toes assume an indicated position or direction
# Synonyms are: ['toe']
# >n
# Is traipse.v.01 an appropriate substitute for go? (y/n)
# It means: walk or tramp about
# Synonyms are: ['traipse', 'shlep']
# >n
# Is tramp_down.v.01 an appropriate substitute for go? (y/n)
# It means: walk on and flatten
# Synonyms are: ['tramp down', 'trample', 'tread down']
# >n
# Is tread.v.02 an appropriate substitute for go? (y/n)
# It means: tread or stomp heavily or roughly
# Synonyms are: ['tread', 'trample']
# >y
# Is wade.v.01 an appropriate substitute for go? (y/n)
# It means: walk (through relatively shallow water)
# Synonyms are: ['wade']
# >y
# Is snake.v.03 an appropriate substitute for go? (y/n)
# It means: move along a winding path
# Synonyms are: ['snake']
# >n
# Is bowl.v.01 an appropriate substitute for go? (y/n)
# It means: roll (a ball)
# Synonyms are: ['bowl']
# >n
# Is troll.v.02 an appropriate substitute for go? (y/n)
# It means: cause to move round and round
# Synonyms are: ['troll']
# >n
# Is freewheel.v.02 an appropriate substitute for go? (y/n)
# It means: coast in a vehicle using the freewheel
# Synonyms are: ['freewheel']
# >n
# Is side-slip.v.01 an appropriate substitute for go? (y/n)
# It means: slide sideways through the air in a downward direction in an airplane along an inclined lateral axis
# Synonyms are: ['side-slip']
# >n
# Is skid.v.01 an appropriate substitute for go? (y/n)
# It means: slide without control
# Synonyms are: ['skid']
# >n
# Is submarine.v.01 an appropriate substitute for go? (y/n)
# It means: move forward or under in a sliding motion
# Synonyms are: ['submarine']
# >n
# Is take.v.27 an appropriate substitute for go? (y/n)
# It means: head into a specified direction
# Synonyms are: ['take', 'make']
# >n
# Is rip.v.02 an appropriate substitute for go? (y/n)
# It means: move precipitously or violently
# Synonyms are: ['rip']
# >n
# Is butterfly.v.01 an appropriate substitute for go? (y/n)
# It means: flutter like a butterfly
# Synonyms are: ['butterfly']
# >n
# Is hare.v.01 an appropriate substitute for go? (y/n)
# It means: run quickly, like a hare
# Synonyms are: ['hare']
# >n
# Is jog.v.03 an appropriate substitute for go? (y/n)
# It means: run for exercise
# Synonyms are: ['jog']
# >y
# Is lope.v.01 an appropriate substitute for go? (y/n)
# It means: run easily
# Synonyms are: ['lope']
# >y
# Is outrun.v.01 an appropriate substitute for go? (y/n)
# It means: run faster than
# Synonyms are: ['outrun']
# >n
# Is romp.v.02 an appropriate substitute for go? (y/n)
# It means: run easily and fairly fast
# Synonyms are: ['romp']
# >y
# Is run.v.33 an appropriate substitute for go? (y/n)
# It means: run with the ball; in such sports as football
# Synonyms are: ['run']
# >y
# Is run_bases.v.01 an appropriate substitute for go? (y/n)
# It means: run around the bases, in baseball
# Synonyms are: ['run bases']
# >n
# Is rush.v.05 an appropriate substitute for go? (y/n)
# It means: run with the ball, in football
# Synonyms are: ['rush']
# >y
# Is scurry.v.01 an appropriate substitute for go? (y/n)
# It means: to move about or proceed hurriedly
# Synonyms are: ['scurry', 'scamper', 'skitter', 'scuttle']
# >y
# Is sprint.v.01 an appropriate substitute for go? (y/n)
# It means: run very fast, usually for a short distance
# Synonyms are: ['sprint']
# >y
# Is streak.v.02 an appropriate substitute for go? (y/n)
# It means: run naked in a public place
# Synonyms are: ['streak']
# >y
# Is trot.v.01 an appropriate substitute for go? (y/n)
# It means: run at a moderately swift pace
# Synonyms are: ['trot', 'jog', 'clip']
# >y
# Is backpack.v.01 an appropriate substitute for go? (y/n)
# It means: hike with a backpack
# Synonyms are: ['backpack', 'pack']
# >n
# Is tramp.v.01 an appropriate substitute for go? (y/n)
# It means: travel on foot, especially on a walking expedition
# Synonyms are: ['tramp']
# >y
# Is countermarch.v.01 an appropriate substitute for go? (y/n)
# It means: march back along the same way
# Synonyms are: ['countermarch']
# >n
# Is debouch.v.01 an appropriate substitute for go? (y/n)
# It means: march out (as from a defile) into open ground
# Synonyms are: ['debouch', 'march out']
# >n
# Is file.v.03 an appropriate substitute for go? (y/n)
# It means: proceed in line
# Synonyms are: ['file']
# >n
# Is goose_step.v.01 an appropriate substitute for go? (y/n)
# It means: march in a military fashion
# Synonyms are: ['goose step']
# >n
# Is parade.v.02 an appropriate substitute for go? (y/n)
# It means: march in a procession
# Synonyms are: ['parade', 'troop', 'promenade']
# >n
# Is troop.v.02 an appropriate substitute for go? (y/n)
# It means: move or march as if in a crowd
# Synonyms are: ['troop']
# >n
# Is scuff.v.01 an appropriate substitute for go? (y/n)
# It means: walk without lifting the feet
# Synonyms are: ['scuff', 'drag']
# >n
# Is squelch.v.03 an appropriate substitute for go? (y/n)
# It means: walk through mud or mire
# Synonyms are: ['squelch', 'squish', 'splash', 'splosh', 'slosh', 'slop']
# >n
# Is treadle.v.01 an appropriate substitute for go? (y/n)
# It means: tread over
# Synonyms are: ['treadle']
# >n
# Is puddle.v.01 an appropriate substitute for go? (y/n)
# It means: wade or dabble in a puddle
# Synonyms are: ['puddle']
# >n
# Is crab.v.02 an appropriate substitute for go? (y/n)
# It means: scurry sideways like a crab
# Synonyms are: ['crab']
# >n
# First, pick the word sense for the word 'north'
# ==============
#
# Next, pick which hypernyms of north.n.03 we should allow players to use.
# ==============
# NORTH
# Is cardinal_compass_point.n.01 an appropriate substitute for north? (y/n)
# It means: one of the four main compass points
# Synonyms are: ['cardinal compass point']
# >n
# \Finally, pick which hyponyms of north.n.03 we should allow players to use.
# ==============
# NORTH
# You're done annotating!  Save your annotation to your Google drive.
# You need to paste in a confirmation code to allow Colab to have access.
# We'll create a file called 'word-sense-annotations.json' for you to turn in.
# ==============
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# ## Look Over Your Annotations
#
# Here's what your selections were, and what their corresponding synonyms are.

# %%
for word in word_senses:
  print('\n', word.upper())
  word_sense = wn.synset(word_senses[word])
  print('Synonyms:\t', get_synonyms(word_sense))
  print('Hypernyms:', )
  for hypernym in confirmed_hypernyms[word]:
    print('\t', get_synonyms(wn.synset(hypernym)))

  print('Hyponyms:', )
  hyponyms = confirmed_hyponyms[word]
  for hyponym in hyponyms:
    print('\t', get_synonyms(wn.synset(hyponym)))
# Out:
#  WEAR
# Synonyms:	 ['wear', 'put on', 'get into', 'don', 'assume']
# Hypernyms:
# Hyponyms:
# 	 ['slip on']
# 	 ['try on', 'try']
#
#  CROWN
# Synonyms:	 ['crown']
# Hypernyms:
# Hyponyms:
#
#  SMELL
# Synonyms:	 ['smell']
# Hypernyms:
# Hyponyms:
# 	 ['get a noseful', 'get a whiff']
# 	 ['sniff', 'whiff']
# 	 ['snuff', 'snuffle']
#
#  ROSE
# Synonyms:	 ['rose', 'rosebush']
# Hypernyms:
# Hyponyms:
#
#  EAT
# Synonyms:	 ['eat']
# Hypernyms:
# 	 ['consume', 'ingest', 'take in', 'take', 'have']
# Hyponyms:
# 	 ['eat']
# 	 ['devour', 'down', 'consume', 'go through']
# 	 ['eat up', 'finish', 'polish off']
# 	 ['garbage down', 'gobble up', 'shovel in', 'bolt down']
# 	 ['gluttonize', 'gluttonise', 'fress']
# 	 ['gobble', 'bolt']
# 	 ['slurp']
# 	 ['wash down']
# 	 ['wolf', 'wolf down']
#
#  FISH
# Synonyms:	 ['fish']
# Hypernyms:
# 	 ['aquatic vertebrate']
# Hyponyms:
# 	 ['bony fish']
# 	 ['bottom-feeder', 'bottom-dweller']
# 	 ['cartilaginous fish', 'chondrichthian']
# 	 ['food fish']
# 	 ['game fish', 'sport fish']
#
#  LIGHT
# Synonyms:	 ['ignite', 'light']
# Hypernyms:
# 	 ['burn', 'combust']
# Hyponyms:
# 	 ['flare up']
# 	 ['kindle', 'enkindle', 'conflagrate', 'inflame']
# 	 ['light up']
# 	 ['light up', 'fire up', 'light']
# 	 ['reignite']
# 	 ['kindle', 'inflame']
# 	 ['rekindle']
#
#  LAMP
# Synonyms:	 ['lamp']
# Hypernyms:
# 	 ['source of illumination']
# Hyponyms:
# 	 ['lantern']
#
#  GIVE
# Synonyms:	 ['give']
# Hypernyms:
# 	 ['transfer']
# Hyponyms:
# 	 ['accord', 'allot', 'grant']
# 	 ['allow', 'grant']
# 	 ['bestow']
# 	 ['concede', 'yield', 'cede', 'grant']
# 	 ['contribute', 'give', 'chip in', 'kick in']
# 	 ['cough up', 'pony up', 'spit up']
# 	 ['distribute', 'administer', 'mete out', 'deal', 'parcel out', 'lot', 'dispense', 'shell out', 'deal out', 'dish out', 'allot', 'dole out']
# 	 ['lend', 'loan']
# 	 ['offer', 'proffer']
# 	 ['present', 'submit']
# 	 ['provide', 'supply', 'ply', 'cater']
# 	 ['supply', 'provide', 'render', 'furnish']
# 	 ['vest']
# 	 ['give']
# 	 ['assign', 'allot', 'portion']
# 	 ['give', 'apply']
# 	 ['reallot']
# 	 ['cater']
# 	 ['feed']
# 	 ['feed', 'give']
# 	 ['feed']
# 	 ['serve', 'serve up', 'dish out', 'dish up', 'dish']
# 	 ['extend', 'offer']
# 	 ['feed']
#
#  TROLL
# Synonyms:	 ['troll']
# Hypernyms:
# Hyponyms:
#
#  PROPOSE
# Synonyms:	 ['propose', 'declare oneself', 'offer', 'pop the question']
# Hypernyms:
# Hyponyms:
#
#  PRINCESS
# Synonyms:	 ['princess']
# Hypernyms:
# 	 ['aristocrat', 'blue blood', 'patrician']
# Hyponyms:
# 	 ['crown princess']
# 	 ['princess royal']
#
#  GO
# Synonyms:	 ['travel', 'go', 'move', 'locomote']
# Hypernyms:
# Hyponyms:
# 	 ['follow', 'travel along']
# 	 ['glide']
# 	 ['hurtle']
# 	 ['lurch']
# 	 ['pace']
# 	 ['prance']
# 	 ['precess']
# 	 ['proceed', 'go forward', 'continue']
# 	 ['propagate']
# 	 ['pursue', 'follow']
# 	 ['push']
# 	 ['retreat']
# 	 ['roll', 'wander', 'swan', 'stray', 'tramp', 'roam', 'cast', 'ramble', 'rove', 'range', 'drift', 'vagabond']
# 	 ['run']
# 	 ['run']
# 	 ['rush', 'hotfoot', 'hasten', 'hie', 'speed', 'race', 'pelt along', 'rush along', 'cannonball along', 'bucket along', 'belt along', 'step on it']
# 	 ['scramble']
# 	 ['shuttle']
# 	 ['slither', 'slide']
# 	 ['speed']
# 	 ['stray', 'err', 'drift']
# 	 ['trail', 'shack']
# 	 ['travel', 'journey']
# 	 ['travel rapidly', 'speed', 'hurry', 'zip']
# 	 ['walk']
# 	 ['weave', 'wind', 'thread', 'meander', 'wander']
# 	 ['wend']
# 	 ['wheel', 'roll']
# 	 ['whisk']
# 	 ['zigzag', 'crank']
# 	 ['zoom']
# 	 ['coast']
# 	 ['skid', 'slip', 'slue', 'slew', 'slide']
# 	 ['skitter']
# 	 ['snake']
# 	 ['gallop']
# 	 ['walk']
# 	 ['head']
# 	 ['limp']
# 	 ['wander']
# 	 ['haunt', 'stalk']
# 	 ['stalk']
# 	 ['gallivant', 'gad', 'jazz around']
# 	 ['maunder']
# 	 ['tear', 'shoot', 'shoot down', 'charge', 'buck']
# 	 ['cruise']
# 	 ['flit', 'flutter', 'fleet', 'dart']
# 	 ['run']
# 	 ['zoom', 'zoom along', 'whizz', 'whizz along']
# 	 ['amble', 'mosey']
# 	 ['ambulate']
# 	 ['clump', 'clomp']
# 	 ['flounce']
# 	 ['hike']
# 	 ['lollop']
# 	 ['lumber', 'pound']
# 	 ['march', 'process']
# 	 ['march']
# 	 ['mince']
# 	 ['pace']
# 	 ['promenade']
# 	 ['prowl']
# 	 ['shuffle', 'scuffle', 'shamble']
# 	 ['skulk']
# 	 ['slink']
# 	 ['slog', 'footslog', 'plod', 'trudge', 'pad', 'tramp']
# 	 ['slouch']
# 	 ['sneak', 'mouse', 'creep', 'pussyfoot']
# 	 ['stagger', 'reel', 'keel', 'lurch', 'swag', 'careen']
# 	 ['stagger', 'flounder']
# 	 ['step']
# 	 ['stomp', 'stamp', 'stump']
# 	 ['stride']
# 	 ['stroll', 'saunter']
# 	 ['stumble', 'falter', 'bumble']
# 	 ['tap']
# 	 ['tiptoe', 'tip', 'tippytoe']
# 	 ['tittup', 'swagger', 'ruffle', 'prance', 'strut', 'sashay', 'cock']
# 	 ['toddle', 'coggle', 'totter', 'dodder', 'paddle', 'waddle']
# 	 ['tread', 'trample']
# 	 ['wade']
# 	 ['jog']
# 	 ['lope']
# 	 ['romp']
# 	 ['run']
# 	 ['rush']
# 	 ['scurry', 'scamper', 'skitter', 'scuttle']
# 	 ['sprint']
# 	 ['streak']
# 	 ['trot', 'jog', 'clip']
# 	 ['tramp']
#
#  NORTH
# Synonyms:	 ['north', 'due north', 'northward', 'N']
# Hypernyms:
# Hyponyms:

# %% [markdown]
# ## Enumerate Alternatives Wordings of Commands
#
# Once we know what the word sense is for each word in our command, and what its relevant hypernyms and hyponyms are, we can output a rich set of reasonably accurate paraphrases for the commands in our game.
#
# Here we use the

# %%
import itertools #We're using the product method from itertools

def get_alternatives(word, word_senses, confirmed_hypernyms, confirmed_hyponyms):
  """Create a list of good alternatives for a word by listing out the synonyms
    for its word sense, and for its hyponyms and hypernyms."""
  alternatives = []
  if not word in word_senses:
    alternatives.append(word)
    return alternatives
  word_sense = wn.synset(word_senses[word])
  alternatives.extend(get_synonyms(word_sense))
  for hypernym in confirmed_hypernyms[word]:
    alternatives.extend(get_synonyms(wn.synset(hypernym)))
  for hyponym in confirmed_hyponyms[word]:
    alternatives.extend(get_synonyms(wn.synset(hyponym)))
  return alternatives

def enumerate_alternatives(sentence, word_senses, confirmed_hypernyms, confirmed_hyponyms):
  """Enumerate all of the sentenes that can result by taking any combination of
     the alternates for each word in the sentence."""
  words = word_tokenize(sentence.lower())
  # a list of lists
  alternatives_per_word = []
  for word in words:
    alternatives = get_alternatives(word, word_senses, confirmed_hypernyms, confirmed_hyponyms)
    alternatives_per_word.append(alternatives)
  
  alternative_to_original = {}
  # all combinations of a list of lists
  for words in list(itertools.product(*alternatives_per_word)):
    alt_sent = " ".join(words)
    alternative_to_original[alt_sent] = sentence
  return alternative_to_original


# alternative_commands is a dictionary that maps 
# the new commands onto the original ones.
alternative_commands = {}
for command in commands:
  alternative_commands.update(enumerate_alternatives(command, 
                                                     word_senses, 
                                                     confirmed_hypernyms, 
                                                     confirmed_hyponyms))

for alt_sent in alternative_commands:
  print("%s ==> %s" % (alt_sent, alternative_commands[alt_sent]))
print("Congratulations you can now handle %d commands instead of just %d!" % 
      (len(alternative_commands.keys()), len(commands)))
# Out:
# wear crown ==> wear crown
# put on crown ==> wear crown
# get into crown ==> wear crown
# don crown ==> wear crown
# assume crown ==> wear crown
# slip on crown ==> wear crown
# try on crown ==> wear crown
# try crown ==> wear crown
# smell rose ==> smell rose
# smell rosebush ==> smell rose
# get a noseful rose ==> smell rose
# get a noseful rosebush ==> smell rose
# get a whiff rose ==> smell rose
# get a whiff rosebush ==> smell rose
# sniff rose ==> smell rose
# sniff rosebush ==> smell rose
# whiff rose ==> smell rose
# whiff rosebush ==> smell rose
# snuff rose ==> smell rose
# snuff rosebush ==> smell rose
# snuffle rose ==> smell rose
# snuffle rosebush ==> smell rose
# eat fish ==> eat fish
# eat aquatic vertebrate ==> eat fish
# eat bony fish ==> eat fish
# eat bottom-feeder ==> eat fish
# eat bottom-dweller ==> eat fish
# eat cartilaginous fish ==> eat fish
# eat chondrichthian ==> eat fish
# eat food fish ==> eat fish
# eat game fish ==> eat fish
# eat sport fish ==> eat fish
# consume fish ==> eat fish
# consume aquatic vertebrate ==> eat fish
# consume bony fish ==> eat fish
# consume bottom-feeder ==> eat fish
# consume bottom-dweller ==> eat fish
# consume cartilaginous fish ==> eat fish
# consume chondrichthian ==> eat fish
# consume food fish ==> eat fish
# consume game fish ==> eat fish
# consume sport fish ==> eat fish
# ingest fish ==> eat fish
# ingest aquatic vertebrate ==> eat fish
# ingest bony fish ==> eat fish
# ingest bottom-feeder ==> eat fish
# ingest bottom-dweller ==> eat fish
# ingest cartilaginous fish ==> eat fish
# ingest chondrichthian ==> eat fish
# ingest food fish ==> eat fish
# ingest game fish ==> eat fish
# ingest sport fish ==> eat fish
# take in fish ==> eat fish
# take in aquatic vertebrate ==> eat fish
# take in bony fish ==> eat fish
# take in bottom-feeder ==> eat fish
# take in bottom-dweller ==> eat fish
# take in cartilaginous fish ==> eat fish
# take in chondrichthian ==> eat fish
# take in food fish ==> eat fish
# take in game fish ==> eat fish
# take in sport fish ==> eat fish
# take fish ==> eat fish
# take aquatic vertebrate ==> eat fish
# take bony fish ==> eat fish
# take bottom-feeder ==> eat fish
# take bottom-dweller ==> eat fish
# take cartilaginous fish ==> eat fish
# take chondrichthian ==> eat fish
# take food fish ==> eat fish
# take game fish ==> eat fish
# take sport fish ==> eat fish
# have fish ==> eat fish
# have aquatic vertebrate ==> eat fish
# have bony fish ==> eat fish
# have bottom-feeder ==> eat fish
# have bottom-dweller ==> eat fish
# have cartilaginous fish ==> eat fish
# have chondrichthian ==> eat fish
# have food fish ==> eat fish
# have game fish ==> eat fish
# have sport fish ==> eat fish
# devour fish ==> eat fish
# devour aquatic vertebrate ==> eat fish
# devour bony fish ==> eat fish
# devour bottom-feeder ==> eat fish
# devour bottom-dweller ==> eat fish
# devour cartilaginous fish ==> eat fish
# devour chondrichthian ==> eat fish
# devour food fish ==> eat fish
# devour game fish ==> eat fish
# devour sport fish ==> eat fish
# down fish ==> eat fish
# down aquatic vertebrate ==> eat fish
# down bony fish ==> eat fish
# down bottom-feeder ==> eat fish
# down bottom-dweller ==> eat fish
# down cartilaginous fish ==> eat fish
# down chondrichthian ==> eat fish
# down food fish ==> eat fish
# down game fish ==> eat fish
# down sport fish ==> eat fish
# go through fish ==> eat fish
# go through aquatic vertebrate ==> eat fish
# go through bony fish ==> eat fish
# go through bottom-feeder ==> eat fish
# go through bottom-dweller ==> eat fish
# go through cartilaginous fish ==> eat fish
# go through chondrichthian ==> eat fish
# go through food fish ==> eat fish
# go through game fish ==> eat fish
# go through sport fish ==> eat fish
# eat up fish ==> eat fish
# eat up aquatic vertebrate ==> eat fish
# eat up bony fish ==> eat fish
# eat up bottom-feeder ==> eat fish
# eat up bottom-dweller ==> eat fish
# eat up cartilaginous fish ==> eat fish
# eat up chondrichthian ==> eat fish
# eat up food fish ==> eat fish
# eat up game fish ==> eat fish
# eat up sport fish ==> eat fish
# finish fish ==> eat fish
# finish aquatic vertebrate ==> eat fish
# finish bony fish ==> eat fish
# finish bottom-feeder ==> eat fish
# finish bottom-dweller ==> eat fish
# finish cartilaginous fish ==> eat fish
# finish chondrichthian ==> eat fish
# finish food fish ==> eat fish
# finish game fish ==> eat fish
# finish sport fish ==> eat fish
# polish off fish ==> eat fish
# polish off aquatic vertebrate ==> eat fish
# polish off bony fish ==> eat fish
# polish off bottom-feeder ==> eat fish
# polish off bottom-dweller ==> eat fish
# polish off cartilaginous fish ==> eat fish
# polish off chondrichthian ==> eat fish
# polish off food fish ==> eat fish
# polish off game fish ==> eat fish
# polish off sport fish ==> eat fish
# garbage down fish ==> eat fish
# garbage down aquatic vertebrate ==> eat fish
# garbage down bony fish ==> eat fish
# garbage down bottom-feeder ==> eat fish
# garbage down bottom-dweller ==> eat fish
# garbage down cartilaginous fish ==> eat fish
# garbage down chondrichthian ==> eat fish
# garbage down food fish ==> eat fish
# garbage down game fish ==> eat fish
# garbage down sport fish ==> eat fish
# gobble up fish ==> eat fish
# gobble up aquatic vertebrate ==> eat fish
# gobble up bony fish ==> eat fish
# gobble up bottom-feeder ==> eat fish
# gobble up bottom-dweller ==> eat fish
# gobble up cartilaginous fish ==> eat fish
# gobble up chondrichthian ==> eat fish
# gobble up food fish ==> eat fish
# gobble up game fish ==> eat fish
# gobble up sport fish ==> eat fish
# shovel in fish ==> eat fish
# shovel in aquatic vertebrate ==> eat fish
# shovel in bony fish ==> eat fish
# shovel in bottom-feeder ==> eat fish
# shovel in bottom-dweller ==> eat fish
# shovel in cartilaginous fish ==> eat fish
# shovel in chondrichthian ==> eat fish
# shovel in food fish ==> eat fish
# shovel in game fish ==> eat fish
# shovel in sport fish ==> eat fish
# bolt down fish ==> eat fish
# bolt down aquatic vertebrate ==> eat fish
# bolt down bony fish ==> eat fish
# bolt down bottom-feeder ==> eat fish
# bolt down bottom-dweller ==> eat fish
# bolt down cartilaginous fish ==> eat fish
# bolt down chondrichthian ==> eat fish
# bolt down food fish ==> eat fish
# bolt down game fish ==> eat fish
# bolt down sport fish ==> eat fish
# gluttonize fish ==> eat fish
# gluttonize aquatic vertebrate ==> eat fish
# gluttonize bony fish ==> eat fish
# gluttonize bottom-feeder ==> eat fish
# gluttonize bottom-dweller ==> eat fish
# gluttonize cartilaginous fish ==> eat fish
# gluttonize chondrichthian ==> eat fish
# gluttonize food fish ==> eat fish
# gluttonize game fish ==> eat fish
# gluttonize sport fish ==> eat fish
# gluttonise fish ==> eat fish
# gluttonise aquatic vertebrate ==> eat fish
# gluttonise bony fish ==> eat fish
# gluttonise bottom-feeder ==> eat fish
# gluttonise bottom-dweller ==> eat fish
# gluttonise cartilaginous fish ==> eat fish
# gluttonise chondrichthian ==> eat fish
# gluttonise food fish ==> eat fish
# gluttonise game fish ==> eat fish
# gluttonise sport fish ==> eat fish
# fress fish ==> eat fish
# fress aquatic vertebrate ==> eat fish
# fress bony fish ==> eat fish
# fress bottom-feeder ==> eat fish
# fress bottom-dweller ==> eat fish
# fress cartilaginous fish ==> eat fish
# fress chondrichthian ==> eat fish
# fress food fish ==> eat fish
# fress game fish ==> eat fish
# fress sport fish ==> eat fish
# gobble fish ==> eat fish
# gobble aquatic vertebrate ==> eat fish
# gobble bony fish ==> eat fish
# gobble bottom-feeder ==> eat fish
# gobble bottom-dweller ==> eat fish
# gobble cartilaginous fish ==> eat fish
# gobble chondrichthian ==> eat fish
# gobble food fish ==> eat fish
# gobble game fish ==> eat fish
# gobble sport fish ==> eat fish
# bolt fish ==> eat fish
# bolt aquatic vertebrate ==> eat fish
# bolt bony fish ==> eat fish
# bolt bottom-feeder ==> eat fish
# bolt bottom-dweller ==> eat fish
# bolt cartilaginous fish ==> eat fish
# bolt chondrichthian ==> eat fish
# bolt food fish ==> eat fish
# bolt game fish ==> eat fish
# bolt sport fish ==> eat fish
# slurp fish ==> eat fish
# slurp aquatic vertebrate ==> eat fish
# slurp bony fish ==> eat fish
# slurp bottom-feeder ==> eat fish
# slurp bottom-dweller ==> eat fish
# slurp cartilaginous fish ==> eat fish
# slurp chondrichthian ==> eat fish
# slurp food fish ==> eat fish
# slurp game fish ==> eat fish
# slurp sport fish ==> eat fish
# wash down fish ==> eat fish
# wash down aquatic vertebrate ==> eat fish
# wash down bony fish ==> eat fish
# wash down bottom-feeder ==> eat fish
# wash down bottom-dweller ==> eat fish
# wash down cartilaginous fish ==> eat fish
# wash down chondrichthian ==> eat fish
# wash down food fish ==> eat fish
# wash down game fish ==> eat fish
# wash down sport fish ==> eat fish
# wolf fish ==> eat fish
# wolf aquatic vertebrate ==> eat fish
# wolf bony fish ==> eat fish
# wolf bottom-feeder ==> eat fish
# wolf bottom-dweller ==> eat fish
# wolf cartilaginous fish ==> eat fish
# wolf chondrichthian ==> eat fish
# wolf food fish ==> eat fish
# wolf game fish ==> eat fish
# wolf sport fish ==> eat fish
# wolf down fish ==> eat fish
# wolf down aquatic vertebrate ==> eat fish
# wolf down bony fish ==> eat fish
# wolf down bottom-feeder ==> eat fish
# wolf down bottom-dweller ==> eat fish
# wolf down cartilaginous fish ==> eat fish
# wolf down chondrichthian ==> eat fish
# wolf down food fish ==> eat fish
# wolf down game fish ==> eat fish
# wolf down sport fish ==> eat fish
# ignite lamp ==> light lamp
# ignite source of illumination ==> light lamp
# ignite lantern ==> light lamp
# light lamp ==> light lamp
# light source of illumination ==> light lamp
# light lantern ==> light lamp
# burn lamp ==> light lamp
# burn source of illumination ==> light lamp
# burn lantern ==> light lamp
# combust lamp ==> light lamp
# combust source of illumination ==> light lamp
# combust lantern ==> light lamp
# flare up lamp ==> light lamp
# flare up source of illumination ==> light lamp
# flare up lantern ==> light lamp
# kindle lamp ==> light lamp
# kindle source of illumination ==> light lamp
# kindle lantern ==> light lamp
# enkindle lamp ==> light lamp
# enkindle source of illumination ==> light lamp
# enkindle lantern ==> light lamp
# conflagrate lamp ==> light lamp
# conflagrate source of illumination ==> light lamp
# conflagrate lantern ==> light lamp
# inflame lamp ==> light lamp
# inflame source of illumination ==> light lamp
# inflame lantern ==> light lamp
# light up lamp ==> light lamp
# light up source of illumination ==> light lamp
# light up lantern ==> light lamp
# fire up lamp ==> light lamp
# fire up source of illumination ==> light lamp
# fire up lantern ==> light lamp
# reignite lamp ==> light lamp
# reignite source of illumination ==> light lamp
# reignite lantern ==> light lamp
# rekindle lamp ==> light lamp
# rekindle source of illumination ==> light lamp
# rekindle lantern ==> light lamp
# give fish to troll ==> give fish to troll
# give aquatic vertebrate to troll ==> give fish to troll
# give bony fish to troll ==> give fish to troll
# give bottom-feeder to troll ==> give fish to troll
# give bottom-dweller to troll ==> give fish to troll
# give cartilaginous fish to troll ==> give fish to troll
# give chondrichthian to troll ==> give fish to troll
# give food fish to troll ==> give fish to troll
# give game fish to troll ==> give fish to troll
# give sport fish to troll ==> give fish to troll
# transfer fish to troll ==> give fish to troll
# transfer aquatic vertebrate to troll ==> give fish to troll
# transfer bony fish to troll ==> give fish to troll
# transfer bottom-feeder to troll ==> give fish to troll
# transfer bottom-dweller to troll ==> give fish to troll
# transfer cartilaginous fish to troll ==> give fish to troll
# transfer chondrichthian to troll ==> give fish to troll
# transfer food fish to troll ==> give fish to troll
# transfer game fish to troll ==> give fish to troll
# transfer sport fish to troll ==> give fish to troll
# accord fish to troll ==> give fish to troll
# accord aquatic vertebrate to troll ==> give fish to troll
# accord bony fish to troll ==> give fish to troll
# accord bottom-feeder to troll ==> give fish to troll
# accord bottom-dweller to troll ==> give fish to troll
# accord cartilaginous fish to troll ==> give fish to troll
# accord chondrichthian to troll ==> give fish to troll
# accord food fish to troll ==> give fish to troll
# accord game fish to troll ==> give fish to troll
# accord sport fish to troll ==> give fish to troll
# allot fish to troll ==> give fish to troll
# allot aquatic vertebrate to troll ==> give fish to troll
# allot bony fish to troll ==> give fish to troll
# allot bottom-feeder to troll ==> give fish to troll
# allot bottom-dweller to troll ==> give fish to troll
# allot cartilaginous fish to troll ==> give fish to troll
# allot chondrichthian to troll ==> give fish to troll
# allot food fish to troll ==> give fish to troll
# allot game fish to troll ==> give fish to troll
# allot sport fish to troll ==> give fish to troll
# grant fish to troll ==> give fish to troll
# grant aquatic vertebrate to troll ==> give fish to troll
# grant bony fish to troll ==> give fish to troll
# grant bottom-feeder to troll ==> give fish to troll
# grant bottom-dweller to troll ==> give fish to troll
# grant cartilaginous fish to troll ==> give fish to troll
# grant chondrichthian to troll ==> give fish to troll
# grant food fish to troll ==> give fish to troll
# grant game fish to troll ==> give fish to troll
# grant sport fish to troll ==> give fish to troll
# allow fish to troll ==> give fish to troll
# allow aquatic vertebrate to troll ==> give fish to troll
# allow bony fish to troll ==> give fish to troll
# allow bottom-feeder to troll ==> give fish to troll
# allow bottom-dweller to troll ==> give fish to troll
# allow cartilaginous fish to troll ==> give fish to troll
# allow chondrichthian to troll ==> give fish to troll
# allow food fish to troll ==> give fish to troll
# allow game fish to troll ==> give fish to troll
# allow sport fish to troll ==> give fish to troll
# bestow fish to troll ==> give fish to troll
# bestow aquatic vertebrate to troll ==> give fish to troll
# bestow bony fish to troll ==> give fish to troll
# bestow bottom-feeder to troll ==> give fish to troll
# bestow bottom-dweller to troll ==> give fish to troll
# bestow cartilaginous fish to troll ==> give fish to troll
# bestow chondrichthian to troll ==> give fish to troll
# bestow food fish to troll ==> give fish to troll
# bestow game fish to troll ==> give fish to troll
# bestow sport fish to troll ==> give fish to troll
# concede fish to troll ==> give fish to troll
# concede aquatic vertebrate to troll ==> give fish to troll
# concede bony fish to troll ==> give fish to troll
# concede bottom-feeder to troll ==> give fish to troll
# concede bottom-dweller to troll ==> give fish to troll
# concede cartilaginous fish to troll ==> give fish to troll
# concede chondrichthian to troll ==> give fish to troll
# concede food fish to troll ==> give fish to troll
# concede game fish to troll ==> give fish to troll
# concede sport fish to troll ==> give fish to troll
# yield fish to troll ==> give fish to troll
# yield aquatic vertebrate to troll ==> give fish to troll
# yield bony fish to troll ==> give fish to troll
# yield bottom-feeder to troll ==> give fish to troll
# yield bottom-dweller to troll ==> give fish to troll
# yield cartilaginous fish to troll ==> give fish to troll
# yield chondrichthian to troll ==> give fish to troll
# yield food fish to troll ==> give fish to troll
# yield game fish to troll ==> give fish to troll
# yield sport fish to troll ==> give fish to troll
# cede fish to troll ==> give fish to troll
# cede aquatic vertebrate to troll ==> give fish to troll
# cede bony fish to troll ==> give fish to troll
# cede bottom-feeder to troll ==> give fish to troll
# cede bottom-dweller to troll ==> give fish to troll
# cede cartilaginous fish to troll ==> give fish to troll
# cede chondrichthian to troll ==> give fish to troll
# cede food fish to troll ==> give fish to troll
# cede game fish to troll ==> give fish to troll
# cede sport fish to troll ==> give fish to troll
# contribute fish to troll ==> give fish to troll
# contribute aquatic vertebrate to troll ==> give fish to troll
# contribute bony fish to troll ==> give fish to troll
# contribute bottom-feeder to troll ==> give fish to troll
# contribute bottom-dweller to troll ==> give fish to troll
# contribute cartilaginous fish to troll ==> give fish to troll
# contribute chondrichthian to troll ==> give fish to troll
# contribute food fish to troll ==> give fish to troll
# contribute game fish to troll ==> give fish to troll
# contribute sport fish to troll ==> give fish to troll
# chip in fish to troll ==> give fish to troll
# chip in aquatic vertebrate to troll ==> give fish to troll
# chip in bony fish to troll ==> give fish to troll
# chip in bottom-feeder to troll ==> give fish to troll
# chip in bottom-dweller to troll ==> give fish to troll
# chip in cartilaginous fish to troll ==> give fish to troll
# chip in chondrichthian to troll ==> give fish to troll
# chip in food fish to troll ==> give fish to troll
# chip in game fish to troll ==> give fish to troll
# chip in sport fish to troll ==> give fish to troll
# kick in fish to troll ==> give fish to troll
# kick in aquatic vertebrate to troll ==> give fish to troll
# kick in bony fish to troll ==> give fish to troll
# kick in bottom-feeder to troll ==> give fish to troll
# kick in bottom-dweller to troll ==> give fish to troll
# kick in cartilaginous fish to troll ==> give fish to troll
# kick in chondrichthian to troll ==> give fish to troll
# kick in food fish to troll ==> give fish to troll
# kick in game fish to troll ==> give fish to troll
# kick in sport fish to troll ==> give fish to troll
# cough up fish to troll ==> give fish to troll
# cough up aquatic vertebrate to troll ==> give fish to troll
# cough up bony fish to troll ==> give fish to troll
# cough up bottom-feeder to troll ==> give fish to troll
# cough up bottom-dweller to troll ==> give fish to troll
# cough up cartilaginous fish to troll ==> give fish to troll
# cough up chondrichthian to troll ==> give fish to troll
# cough up food fish to troll ==> give fish to troll
# cough up game fish to troll ==> give fish to troll
# cough up sport fish to troll ==> give fish to troll
# pony up fish to troll ==> give fish to troll
# pony up aquatic vertebrate to troll ==> give fish to troll
# pony up bony fish to troll ==> give fish to troll
# pony up bottom-feeder to troll ==> give fish to troll
# pony up bottom-dweller to troll ==> give fish to troll
# pony up cartilaginous fish to troll ==> give fish to troll
# pony up chondrichthian to troll ==> give fish to troll
# pony up food fish to troll ==> give fish to troll
# pony up game fish to troll ==> give fish to troll
# pony up sport fish to troll ==> give fish to troll
# spit up fish to troll ==> give fish to troll
# spit up aquatic vertebrate to troll ==> give fish to troll
# spit up bony fish to troll ==> give fish to troll
# spit up bottom-feeder to troll ==> give fish to troll
# spit up bottom-dweller to troll ==> give fish to troll
# spit up cartilaginous fish to troll ==> give fish to troll
# spit up chondrichthian to troll ==> give fish to troll
# spit up food fish to troll ==> give fish to troll
# spit up game fish to troll ==> give fish to troll
# spit up sport fish to troll ==> give fish to troll
# distribute fish to troll ==> give fish to troll
# distribute aquatic vertebrate to troll ==> give fish to troll
# distribute bony fish to troll ==> give fish to troll
# distribute bottom-feeder to troll ==> give fish to troll
# distribute bottom-dweller to troll ==> give fish to troll
# distribute cartilaginous fish to troll ==> give fish to troll
# distribute chondrichthian to troll ==> give fish to troll
# distribute food fish to troll ==> give fish to troll
# distribute game fish to troll ==> give fish to troll
# distribute sport fish to troll ==> give fish to troll
# administer fish to troll ==> give fish to troll
# administer aquatic vertebrate to troll ==> give fish to troll
# administer bony fish to troll ==> give fish to troll
# administer bottom-feeder to troll ==> give fish to troll
# administer bottom-dweller to troll ==> give fish to troll
# administer cartilaginous fish to troll ==> give fish to troll
# administer chondrichthian to troll ==> give fish to troll
# administer food fish to troll ==> give fish to troll
# administer game fish to troll ==> give fish to troll
# administer sport fish to troll ==> give fish to troll
# mete out fish to troll ==> give fish to troll
# mete out aquatic vertebrate to troll ==> give fish to troll
# mete out bony fish to troll ==> give fish to troll
# mete out bottom-feeder to troll ==> give fish to troll
# mete out bottom-dweller to troll ==> give fish to troll
# mete out cartilaginous fish to troll ==> give fish to troll
# mete out chondrichthian to troll ==> give fish to troll
# mete out food fish to troll ==> give fish to troll
# mete out game fish to troll ==> give fish to troll
# mete out sport fish to troll ==> give fish to troll
# deal fish to troll ==> give fish to troll
# deal aquatic vertebrate to troll ==> give fish to troll
# deal bony fish to troll ==> give fish to troll
# deal bottom-feeder to troll ==> give fish to troll
# deal bottom-dweller to troll ==> give fish to troll
# deal cartilaginous fish to troll ==> give fish to troll
# deal chondrichthian to troll ==> give fish to troll
# deal food fish to troll ==> give fish to troll
# deal game fish to troll ==> give fish to troll
# deal sport fish to troll ==> give fish to troll
# parcel out fish to troll ==> give fish to troll
# parcel out aquatic vertebrate to troll ==> give fish to troll
# parcel out bony fish to troll ==> give fish to troll
# parcel out bottom-feeder to troll ==> give fish to troll
# parcel out bottom-dweller to troll ==> give fish to troll
# parcel out cartilaginous fish to troll ==> give fish to troll
# parcel out chondrichthian to troll ==> give fish to troll
# parcel out food fish to troll ==> give fish to troll
# parcel out game fish to troll ==> give fish to troll
# parcel out sport fish to troll ==> give fish to troll
# lot fish to troll ==> give fish to troll
# lot aquatic vertebrate to troll ==> give fish to troll
# lot bony fish to troll ==> give fish to troll
# lot bottom-feeder to troll ==> give fish to troll
# lot bottom-dweller to troll ==> give fish to troll
# lot cartilaginous fish to troll ==> give fish to troll
# lot chondrichthian to troll ==> give fish to troll
# lot food fish to troll ==> give fish to troll
# lot game fish to troll ==> give fish to troll
# lot sport fish to troll ==> give fish to troll
# dispense fish to troll ==> give fish to troll
# dispense aquatic vertebrate to troll ==> give fish to troll
# dispense bony fish to troll ==> give fish to troll
# dispense bottom-feeder to troll ==> give fish to troll
# dispense bottom-dweller to troll ==> give fish to troll
# dispense cartilaginous fish to troll ==> give fish to troll
# dispense chondrichthian to troll ==> give fish to troll
# dispense food fish to troll ==> give fish to troll
# dispense game fish to troll ==> give fish to troll
# dispense sport fish to troll ==> give fish to troll
# shell out fish to troll ==> give fish to troll
# shell out aquatic vertebrate to troll ==> give fish to troll
# shell out bony fish to troll ==> give fish to troll
# shell out bottom-feeder to troll ==> give fish to troll
# shell out bottom-dweller to troll ==> give fish to troll
# shell out cartilaginous fish to troll ==> give fish to troll
# shell out chondrichthian to troll ==> give fish to troll
# shell out food fish to troll ==> give fish to troll
# shell out game fish to troll ==> give fish to troll
# shell out sport fish to troll ==> give fish to troll
# deal out fish to troll ==> give fish to troll
# deal out aquatic vertebrate to troll ==> give fish to troll
# deal out bony fish to troll ==> give fish to troll
# deal out bottom-feeder to troll ==> give fish to troll
# deal out bottom-dweller to troll ==> give fish to troll
# deal out cartilaginous fish to troll ==> give fish to troll
# deal out chondrichthian to troll ==> give fish to troll
# deal out food fish to troll ==> give fish to troll
# deal out game fish to troll ==> give fish to troll
# deal out sport fish to troll ==> give fish to troll
# dish out fish to troll ==> give fish to troll
# dish out aquatic vertebrate to troll ==> give fish to troll
# dish out bony fish to troll ==> give fish to troll
# dish out bottom-feeder to troll ==> give fish to troll
# dish out bottom-dweller to troll ==> give fish to troll
# dish out cartilaginous fish to troll ==> give fish to troll
# dish out chondrichthian to troll ==> give fish to troll
# dish out food fish to troll ==> give fish to troll
# dish out game fish to troll ==> give fish to troll
# dish out sport fish to troll ==> give fish to troll
# dole out fish to troll ==> give fish to troll
# dole out aquatic vertebrate to troll ==> give fish to troll
# dole out bony fish to troll ==> give fish to troll
# dole out bottom-feeder to troll ==> give fish to troll
# dole out bottom-dweller to troll ==> give fish to troll
# dole out cartilaginous fish to troll ==> give fish to troll
# dole out chondrichthian to troll ==> give fish to troll
# dole out food fish to troll ==> give fish to troll
# dole out game fish to troll ==> give fish to troll
# dole out sport fish to troll ==> give fish to troll
# lend fish to troll ==> give fish to troll
# lend aquatic vertebrate to troll ==> give fish to troll
# lend bony fish to troll ==> give fish to troll
# lend bottom-feeder to troll ==> give fish to troll
# lend bottom-dweller to troll ==> give fish to troll
# lend cartilaginous fish to troll ==> give fish to troll
# lend chondrichthian to troll ==> give fish to troll
# lend food fish to troll ==> give fish to troll
# lend game fish to troll ==> give fish to troll
# lend sport fish to troll ==> give fish to troll
# loan fish to troll ==> give fish to troll
# loan aquatic vertebrate to troll ==> give fish to troll
# loan bony fish to troll ==> give fish to troll
# loan bottom-feeder to troll ==> give fish to troll
# loan bottom-dweller to troll ==> give fish to troll
# loan cartilaginous fish to troll ==> give fish to troll
# loan chondrichthian to troll ==> give fish to troll
# loan food fish to troll ==> give fish to troll
# loan game fish to troll ==> give fish to troll
# loan sport fish to troll ==> give fish to troll
# offer fish to troll ==> give fish to troll
# offer aquatic vertebrate to troll ==> give fish to troll
# offer bony fish to troll ==> give fish to troll
# offer bottom-feeder to troll ==> give fish to troll
# offer bottom-dweller to troll ==> give fish to troll
# offer cartilaginous fish to troll ==> give fish to troll
# offer chondrichthian to troll ==> give fish to troll
# offer food fish to troll ==> give fish to troll
# offer game fish to troll ==> give fish to troll
# offer sport fish to troll ==> give fish to troll
# proffer fish to troll ==> give fish to troll
# proffer aquatic vertebrate to troll ==> give fish to troll
# proffer bony fish to troll ==> give fish to troll
# proffer bottom-feeder to troll ==> give fish to troll
# proffer bottom-dweller to troll ==> give fish to troll
# proffer cartilaginous fish to troll ==> give fish to troll
# proffer chondrichthian to troll ==> give fish to troll
# proffer food fish to troll ==> give fish to troll
# proffer game fish to troll ==> give fish to troll
# proffer sport fish to troll ==> give fish to troll
# present fish to troll ==> give fish to troll
# present aquatic vertebrate to troll ==> give fish to troll
# present bony fish to troll ==> give fish to troll
# present bottom-feeder to troll ==> give fish to troll
# present bottom-dweller to troll ==> give fish to troll
# present cartilaginous fish to troll ==> give fish to troll
# present chondrichthian to troll ==> give fish to troll
# present food fish to troll ==> give fish to troll
# present game fish to troll ==> give fish to troll
# present sport fish to troll ==> give fish to troll
# submit fish to troll ==> give fish to troll
# submit aquatic vertebrate to troll ==> give fish to troll
# submit bony fish to troll ==> give fish to troll
# submit bottom-feeder to troll ==> give fish to troll
# submit bottom-dweller to troll ==> give fish to troll
# submit cartilaginous fish to troll ==> give fish to troll
# submit chondrichthian to troll ==> give fish to troll
# submit food fish to troll ==> give fish to troll
# submit game fish to troll ==> give fish to troll
# submit sport fish to troll ==> give fish to troll
# provide fish to troll ==> give fish to troll
# provide aquatic vertebrate to troll ==> give fish to troll
# provide bony fish to troll ==> give fish to troll
# provide bottom-feeder to troll ==> give fish to troll
# provide bottom-dweller to troll ==> give fish to troll
# provide cartilaginous fish to troll ==> give fish to troll
# provide chondrichthian to troll ==> give fish to troll
# provide food fish to troll ==> give fish to troll
# provide game fish to troll ==> give fish to troll
# provide sport fish to troll ==> give fish to troll
# supply fish to troll ==> give fish to troll
# supply aquatic vertebrate to troll ==> give fish to troll
# supply bony fish to troll ==> give fish to troll
# supply bottom-feeder to troll ==> give fish to troll
# supply bottom-dweller to troll ==> give fish to troll
# supply cartilaginous fish to troll ==> give fish to troll
# supply chondrichthian to troll ==> give fish to troll
# supply food fish to troll ==> give fish to troll
# supply game fish to troll ==> give fish to troll
# supply sport fish to troll ==> give fish to troll
# ply fish to troll ==> give fish to troll
# ply aquatic vertebrate to troll ==> give fish to troll
# ply bony fish to troll ==> give fish to troll
# ply bottom-feeder to troll ==> give fish to troll
# ply bottom-dweller to troll ==> give fish to troll
# ply cartilaginous fish to troll ==> give fish to troll
# ply chondrichthian to troll ==> give fish to troll
# ply food fish to troll ==> give fish to troll
# ply game fish to troll ==> give fish to troll
# ply sport fish to troll ==> give fish to troll
# cater fish to troll ==> give fish to troll
# cater aquatic vertebrate to troll ==> give fish to troll
# cater bony fish to troll ==> give fish to troll
# cater bottom-feeder to troll ==> give fish to troll
# cater bottom-dweller to troll ==> give fish to troll
# cater cartilaginous fish to troll ==> give fish to troll
# cater chondrichthian to troll ==> give fish to troll
# cater food fish to troll ==> give fish to troll
# cater game fish to troll ==> give fish to troll
# cater sport fish to troll ==> give fish to troll
# render fish to troll ==> give fish to troll
# render aquatic vertebrate to troll ==> give fish to troll
# render bony fish to troll ==> give fish to troll
# render bottom-feeder to troll ==> give fish to troll
# render bottom-dweller to troll ==> give fish to troll
# render cartilaginous fish to troll ==> give fish to troll
# render chondrichthian to troll ==> give fish to troll
# render food fish to troll ==> give fish to troll
# render game fish to troll ==> give fish to troll
# render sport fish to troll ==> give fish to troll
# furnish fish to troll ==> give fish to troll
# furnish aquatic vertebrate to troll ==> give fish to troll
# furnish bony fish to troll ==> give fish to troll
# furnish bottom-feeder to troll ==> give fish to troll
# furnish bottom-dweller to troll ==> give fish to troll
# furnish cartilaginous fish to troll ==> give fish to troll
# furnish chondrichthian to troll ==> give fish to troll
# furnish food fish to troll ==> give fish to troll
# furnish game fish to troll ==> give fish to troll
# furnish sport fish to troll ==> give fish to troll
# vest fish to troll ==> give fish to troll
# vest aquatic vertebrate to troll ==> give fish to troll
# vest bony fish to troll ==> give fish to troll
# vest bottom-feeder to troll ==> give fish to troll
# vest bottom-dweller to troll ==> give fish to troll
# vest cartilaginous fish to troll ==> give fish to troll
# vest chondrichthian to troll ==> give fish to troll
# vest food fish to troll ==> give fish to troll
# vest game fish to troll ==> give fish to troll
# vest sport fish to troll ==> give fish to troll
# assign fish to troll ==> give fish to troll
# assign aquatic vertebrate to troll ==> give fish to troll
# assign bony fish to troll ==> give fish to troll
# assign bottom-feeder to troll ==> give fish to troll
# assign bottom-dweller to troll ==> give fish to troll
# assign cartilaginous fish to troll ==> give fish to troll
# assign chondrichthian to troll ==> give fish to troll
# assign food fish to troll ==> give fish to troll
# assign game fish to troll ==> give fish to troll
# assign sport fish to troll ==> give fish to troll
# portion fish to troll ==> give fish to troll
# portion aquatic vertebrate to troll ==> give fish to troll
# portion bony fish to troll ==> give fish to troll
# portion bottom-feeder to troll ==> give fish to troll
# portion bottom-dweller to troll ==> give fish to troll
# portion cartilaginous fish to troll ==> give fish to troll
# portion chondrichthian to troll ==> give fish to troll
# portion food fish to troll ==> give fish to troll
# portion game fish to troll ==> give fish to troll
# portion sport fish to troll ==> give fish to troll
# apply fish to troll ==> give fish to troll
# apply aquatic vertebrate to troll ==> give fish to troll
# apply bony fish to troll ==> give fish to troll
# apply bottom-feeder to troll ==> give fish to troll
# apply bottom-dweller to troll ==> give fish to troll
# apply cartilaginous fish to troll ==> give fish to troll
# apply chondrichthian to troll ==> give fish to troll
# apply food fish to troll ==> give fish to troll
# apply game fish to troll ==> give fish to troll
# apply sport fish to troll ==> give fish to troll
# reallot fish to troll ==> give fish to troll
# reallot aquatic vertebrate to troll ==> give fish to troll
# reallot bony fish to troll ==> give fish to troll
# reallot bottom-feeder to troll ==> give fish to troll
# reallot bottom-dweller to troll ==> give fish to troll
# reallot cartilaginous fish to troll ==> give fish to troll
# reallot chondrichthian to troll ==> give fish to troll
# reallot food fish to troll ==> give fish to troll
# reallot game fish to troll ==> give fish to troll
# reallot sport fish to troll ==> give fish to troll
# feed fish to troll ==> give fish to troll
# feed aquatic vertebrate to troll ==> give fish to troll
# feed bony fish to troll ==> give fish to troll
# feed bottom-feeder to troll ==> give fish to troll
# feed bottom-dweller to troll ==> give fish to troll
# feed cartilaginous fish to troll ==> give fish to troll
# feed chondrichthian to troll ==> give fish to troll
# feed food fish to troll ==> give fish to troll
# feed game fish to troll ==> give fish to troll
# feed sport fish to troll ==> give fish to troll
# serve fish to troll ==> give fish to troll
# serve aquatic vertebrate to troll ==> give fish to troll
# serve bony fish to troll ==> give fish to troll
# serve bottom-feeder to troll ==> give fish to troll
# serve bottom-dweller to troll ==> give fish to troll
# serve cartilaginous fish to troll ==> give fish to troll
# serve chondrichthian to troll ==> give fish to troll
# serve food fish to troll ==> give fish to troll
# serve game fish to troll ==> give fish to troll
# serve sport fish to troll ==> give fish to troll
# serve up fish to troll ==> give fish to troll
# serve up aquatic vertebrate to troll ==> give fish to troll
# serve up bony fish to troll ==> give fish to troll
# serve up bottom-feeder to troll ==> give fish to troll
# serve up bottom-dweller to troll ==> give fish to troll
# serve up cartilaginous fish to troll ==> give fish to troll
# serve up chondrichthian to troll ==> give fish to troll
# serve up food fish to troll ==> give fish to troll
# serve up game fish to troll ==> give fish to troll
# serve up sport fish to troll ==> give fish to troll
# dish up fish to troll ==> give fish to troll
# dish up aquatic vertebrate to troll ==> give fish to troll
# dish up bony fish to troll ==> give fish to troll
# dish up bottom-feeder to troll ==> give fish to troll
# dish up bottom-dweller to troll ==> give fish to troll
# dish up cartilaginous fish to troll ==> give fish to troll
# dish up chondrichthian to troll ==> give fish to troll
# dish up food fish to troll ==> give fish to troll
# dish up game fish to troll ==> give fish to troll
# dish up sport fish to troll ==> give fish to troll
# dish fish to troll ==> give fish to troll
# dish aquatic vertebrate to troll ==> give fish to troll
# dish bony fish to troll ==> give fish to troll
# dish bottom-feeder to troll ==> give fish to troll
# dish bottom-dweller to troll ==> give fish to troll
# dish cartilaginous fish to troll ==> give fish to troll
# dish chondrichthian to troll ==> give fish to troll
# dish food fish to troll ==> give fish to troll
# dish game fish to troll ==> give fish to troll
# dish sport fish to troll ==> give fish to troll
# extend fish to troll ==> give fish to troll
# extend aquatic vertebrate to troll ==> give fish to troll
# extend bony fish to troll ==> give fish to troll
# extend bottom-feeder to troll ==> give fish to troll
# extend bottom-dweller to troll ==> give fish to troll
# extend cartilaginous fish to troll ==> give fish to troll
# extend chondrichthian to troll ==> give fish to troll
# extend food fish to troll ==> give fish to troll
# extend game fish to troll ==> give fish to troll
# extend sport fish to troll ==> give fish to troll
# propose to the princess ==> propose to the princess
# propose to the aristocrat ==> propose to the princess
# propose to the blue blood ==> propose to the princess
# propose to the patrician ==> propose to the princess
# propose to the crown princess ==> propose to the princess
# propose to the princess royal ==> propose to the princess
# declare oneself to the princess ==> propose to the princess
# declare oneself to the aristocrat ==> propose to the princess
# declare oneself to the blue blood ==> propose to the princess
# declare oneself to the patrician ==> propose to the princess
# declare oneself to the crown princess ==> propose to the princess
# declare oneself to the princess royal ==> propose to the princess
# offer to the princess ==> propose to the princess
# offer to the aristocrat ==> propose to the princess
# offer to the blue blood ==> propose to the princess
# offer to the patrician ==> propose to the princess
# offer to the crown princess ==> propose to the princess
# offer to the princess royal ==> propose to the princess
# pop the question to the princess ==> propose to the princess
# pop the question to the aristocrat ==> propose to the princess
# pop the question to the blue blood ==> propose to the princess
# pop the question to the patrician ==> propose to the princess
# pop the question to the crown princess ==> propose to the princess
# pop the question to the princess royal ==> propose to the princess
# travel north ==> go north
# travel due north ==> go north
# travel northward ==> go north
# travel N ==> go north
# go north ==> go north
# go due north ==> go north
# go northward ==> go north
# go N ==> go north
# move north ==> go north
# move due north ==> go north
# move northward ==> go north
# move N ==> go north
# locomote north ==> go north
# locomote due north ==> go north
# locomote northward ==> go north
# locomote N ==> go north
# follow north ==> go north
# follow due north ==> go north
# follow northward ==> go north
# follow N ==> go north
# travel along north ==> go north
# travel along due north ==> go north
# travel along northward ==> go north
# travel along N ==> go north
# glide north ==> go north
# glide due north ==> go north
# glide northward ==> go north
# glide N ==> go north
# hurtle north ==> go north
# hurtle due north ==> go north
# hurtle northward ==> go north
# hurtle N ==> go north
# lurch north ==> go north
# lurch due north ==> go north
# lurch northward ==> go north
# lurch N ==> go north
# pace north ==> go north
# pace due north ==> go north
# pace northward ==> go north
# pace N ==> go north
# prance north ==> go north
# prance due north ==> go north
# prance northward ==> go north
# prance N ==> go north
# precess north ==> go north
# precess due north ==> go north
# precess northward ==> go north
# precess N ==> go north
# proceed north ==> go north
# proceed due north ==> go north
# proceed northward ==> go north
# proceed N ==> go north
# go forward north ==> go north
# go forward due north ==> go north
# go forward northward ==> go north
# go forward N ==> go north
# continue north ==> go north
# continue due north ==> go north
# continue northward ==> go north
# continue N ==> go north
# propagate north ==> go north
# propagate due north ==> go north
# propagate northward ==> go north
# propagate N ==> go north
# pursue north ==> go north
# pursue due north ==> go north
# pursue northward ==> go north
# pursue N ==> go north
# push north ==> go north
# push due north ==> go north
# push northward ==> go north
# push N ==> go north
# retreat north ==> go north
# retreat due north ==> go north
# retreat northward ==> go north
# retreat N ==> go north
# roll north ==> go north
# roll due north ==> go north
# roll northward ==> go north
# roll N ==> go north
# wander north ==> go north
# wander due north ==> go north
# wander northward ==> go north
# wander N ==> go north
# swan north ==> go north
# swan due north ==> go north
# swan northward ==> go north
# swan N ==> go north
# stray north ==> go north
# stray due north ==> go north
# stray northward ==> go north
# stray N ==> go north
# tramp north ==> go north
# tramp due north ==> go north
# tramp northward ==> go north
# tramp N ==> go north
# roam north ==> go north
# roam due north ==> go north
# roam northward ==> go north
# roam N ==> go north
# cast north ==> go north
# cast due north ==> go north
# cast northward ==> go north
# cast N ==> go north
# ramble north ==> go north
# ramble due north ==> go north
# ramble northward ==> go north
# ramble N ==> go north
# rove north ==> go north
# rove due north ==> go north
# rove northward ==> go north
# rove N ==> go north
# range north ==> go north
# range due north ==> go north
# range northward ==> go north
# range N ==> go north
# drift north ==> go north
# drift due north ==> go north
# drift northward ==> go north
# drift N ==> go north
# vagabond north ==> go north
# vagabond due north ==> go north
# vagabond northward ==> go north
# vagabond N ==> go north
# run north ==> go north
# run due north ==> go north
# run northward ==> go north
# run N ==> go north
# rush north ==> go north
# rush due north ==> go north
# rush northward ==> go north
# rush N ==> go north
# hotfoot north ==> go north
# hotfoot due north ==> go north
# hotfoot northward ==> go north
# hotfoot N ==> go north
# hasten north ==> go north
# hasten due north ==> go north
# hasten northward ==> go north
# hasten N ==> go north
# hie north ==> go north
# hie due north ==> go north
# hie northward ==> go north
# hie N ==> go north
# speed north ==> go north
# speed due north ==> go north
# speed northward ==> go north
# speed N ==> go north
# race north ==> go north
# race due north ==> go north
# race northward ==> go north
# race N ==> go north
# pelt along north ==> go north
# pelt along due north ==> go north
# pelt along northward ==> go north
# pelt along N ==> go north
# rush along north ==> go north
# rush along due north ==> go north
# rush along northward ==> go north
# rush along N ==> go north
# cannonball along north ==> go north
# cannonball along due north ==> go north
# cannonball along northward ==> go north
# cannonball along N ==> go north
# bucket along north ==> go north
# bucket along due north ==> go north
# bucket along northward ==> go north
# bucket along N ==> go north
# belt along north ==> go north
# belt along due north ==> go north
# belt along northward ==> go north
# belt along N ==> go north
# step on it north ==> go north
# step on it due north ==> go north
# step on it northward ==> go north
# step on it N ==> go north
# scramble north ==> go north
# scramble due north ==> go north
# scramble northward ==> go north
# scramble N ==> go north
# shuttle north ==> go north
# shuttle due north ==> go north
# shuttle northward ==> go north
# shuttle N ==> go north
# slither north ==> go north
# slither due north ==> go north
# slither northward ==> go north
# slither N ==> go north
# slide north ==> go north
# slide due north ==> go north
# slide northward ==> go north
# slide N ==> go north
# err north ==> go north
# err due north ==> go north
# err northward ==> go north
# err N ==> go north
# trail north ==> go north
# trail due north ==> go north
# trail northward ==> go north
# trail N ==> go north
# shack north ==> go north
# shack due north ==> go north
# shack northward ==> go north
# shack N ==> go north
# journey north ==> go north
# journey due north ==> go north
# journey northward ==> go north
# journey N ==> go north
# travel rapidly north ==> go north
# travel rapidly due north ==> go north
# travel rapidly northward ==> go north
# travel rapidly N ==> go north
# hurry north ==> go north
# hurry due north ==> go north
# hurry northward ==> go north
# hurry N ==> go north
# zip north ==> go north
# zip due north ==> go north
# zip northward ==> go north
# zip N ==> go north
# walk north ==> go north
# walk due north ==> go north
# walk northward ==> go north
# walk N ==> go north
# weave north ==> go north
# weave due north ==> go north
# weave northward ==> go north
# weave N ==> go north
# wind north ==> go north
# wind due north ==> go north
# wind northward ==> go north
# wind N ==> go north
# thread north ==> go north
# thread due north ==> go north
# thread northward ==> go north
# thread N ==> go north
# meander north ==> go north
# meander due north ==> go north
# meander northward ==> go north
# meander N ==> go north
# wend north ==> go north
# wend due north ==> go north
# wend northward ==> go north
# wend N ==> go north
# wheel north ==> go north
# wheel due north ==> go north
# wheel northward ==> go north
# wheel N ==> go north
# whisk north ==> go north
# whisk due north ==> go north
# whisk northward ==> go north
# whisk N ==> go north
# zigzag north ==> go north
# zigzag due north ==> go north
# zigzag northward ==> go north
# zigzag N ==> go north
# crank north ==> go north
# crank due north ==> go north
# crank northward ==> go north
# crank N ==> go north
# zoom north ==> go north
# zoom due north ==> go north
# zoom northward ==> go north
# zoom N ==> go north
# coast north ==> go north
# coast due north ==> go north
# coast northward ==> go north
# coast N ==> go north
# skid north ==> go north
# skid due north ==> go north
# skid northward ==> go north
# skid N ==> go north
# slip north ==> go north
# slip due north ==> go north
# slip northward ==> go north
# slip N ==> go north
# slue north ==> go north
# slue due north ==> go north
# slue northward ==> go north
# slue N ==> go north
# slew north ==> go north
# slew due north ==> go north
# slew northward ==> go north
# slew N ==> go north
# skitter north ==> go north
# skitter due north ==> go north
# skitter northward ==> go north
# skitter N ==> go north
# snake north ==> go north
# snake due north ==> go north
# snake northward ==> go north
# snake N ==> go north
# gallop north ==> go north
# gallop due north ==> go north
# gallop northward ==> go north
# gallop N ==> go north
# head north ==> go north
# head due north ==> go north
# head northward ==> go north
# head N ==> go north
# limp north ==> go north
# limp due north ==> go north
# limp northward ==> go north
# limp N ==> go north
# haunt north ==> go north
# haunt due north ==> go north
# haunt northward ==> go north
# haunt N ==> go north
# stalk north ==> go north
# stalk due north ==> go north
# stalk northward ==> go north
# stalk N ==> go north
# gallivant north ==> go north
# gallivant due north ==> go north
# gallivant northward ==> go north
# gallivant N ==> go north
# gad north ==> go north
# gad due north ==> go north
# gad northward ==> go north
# gad N ==> go north
# jazz around north ==> go north
# jazz around due north ==> go north
# jazz around northward ==> go north
# jazz around N ==> go north
# maunder north ==> go north
# maunder due north ==> go north
# maunder northward ==> go north
# maunder N ==> go north
# tear north ==> go north
# tear due north ==> go north
# tear northward ==> go north
# tear N ==> go north
# shoot north ==> go north
# shoot due north ==> go north
# shoot northward ==> go north
# shoot N ==> go north
# shoot down north ==> go north
# shoot down due north ==> go north
# shoot down northward ==> go north
# shoot down N ==> go north
# charge north ==> go north
# charge due north ==> go north
# charge northward ==> go north
# charge N ==> go north
# buck north ==> go north
# buck due north ==> go north
# buck northward ==> go north
# buck N ==> go north
# cruise north ==> go north
# cruise due north ==> go north
# cruise northward ==> go north
# cruise N ==> go north
# flit north ==> go north
# flit due north ==> go north
# flit northward ==> go north
# flit N ==> go north
# flutter north ==> go north
# flutter due north ==> go north
# flutter northward ==> go north
# flutter N ==> go north
# fleet north ==> go north
# fleet due north ==> go north
# fleet northward ==> go north
# fleet N ==> go north
# dart north ==> go north
# dart due north ==> go north
# dart northward ==> go north
# dart N ==> go north
# zoom along north ==> go north
# zoom along due north ==> go north
# zoom along northward ==> go north
# zoom along N ==> go north
# whizz north ==> go north
# whizz due north ==> go north
# whizz northward ==> go north
# whizz N ==> go north
# whizz along north ==> go north
# whizz along due north ==> go north
# whizz along northward ==> go north
# whizz along N ==> go north
# amble north ==> go north
# amble due north ==> go north
# amble northward ==> go north
# amble N ==> go north
# mosey north ==> go north
# mosey due north ==> go north
# mosey northward ==> go north
# mosey N ==> go north
# ambulate north ==> go north
# ambulate due north ==> go north
# ambulate northward ==> go north
# ambulate N ==> go north
# clump north ==> go north
# clump due north ==> go north
# clump northward ==> go north
# clump N ==> go north
# clomp north ==> go north
# clomp due north ==> go north
# clomp northward ==> go north
# clomp N ==> go north
# flounce north ==> go north
# flounce due north ==> go north
# flounce northward ==> go north
# flounce N ==> go north
# hike north ==> go north
# hike due north ==> go north
# hike northward ==> go north
# hike N ==> go north
# lollop north ==> go north
# lollop due north ==> go north
# lollop northward ==> go north
# lollop N ==> go north
# lumber north ==> go north
# lumber due north ==> go north
# lumber northward ==> go north
# lumber N ==> go north
# pound north ==> go north
# pound due north ==> go north
# pound northward ==> go north
# pound N ==> go north
# march north ==> go north
# march due north ==> go north
# march northward ==> go north
# march N ==> go north
# process north ==> go north
# process due north ==> go north
# process northward ==> go north
# process N ==> go north
# mince north ==> go north
# mince due north ==> go north
# mince northward ==> go north
# mince N ==> go north
# promenade north ==> go north
# promenade due north ==> go north
# promenade northward ==> go north
# promenade N ==> go north
# prowl north ==> go north
# prowl due north ==> go north
# prowl northward ==> go north
# prowl N ==> go north
# shuffle north ==> go north
# shuffle due north ==> go north
# shuffle northward ==> go north
# shuffle N ==> go north
# scuffle north ==> go north
# scuffle due north ==> go north
# scuffle northward ==> go north
# scuffle N ==> go north
# shamble north ==> go north
# shamble due north ==> go north
# shamble northward ==> go north
# shamble N ==> go north
# skulk north ==> go north
# skulk due north ==> go north
# skulk northward ==> go north
# skulk N ==> go north
# slink north ==> go north
# slink due north ==> go north
# slink northward ==> go north
# slink N ==> go north
# slog north ==> go north
# slog due north ==> go north
# slog northward ==> go north
# slog N ==> go north
# footslog north ==> go north
# footslog due north ==> go north
# footslog northward ==> go north
# footslog N ==> go north
# plod north ==> go north
# plod due north ==> go north
# plod northward ==> go north
# plod N ==> go north
# trudge north ==> go north
# trudge due north ==> go north
# trudge northward ==> go north
# trudge N ==> go north
# pad north ==> go north
# pad due north ==> go north
# pad northward ==> go north
# pad N ==> go north
# slouch north ==> go north
# slouch due north ==> go north
# slouch northward ==> go north
# slouch N ==> go north
# sneak north ==> go north
# sneak due north ==> go north
# sneak northward ==> go north
# sneak N ==> go north
# mouse north ==> go north
# mouse due north ==> go north
# mouse northward ==> go north
# mouse N ==> go north
# creep north ==> go north
# creep due north ==> go north
# creep northward ==> go north
# creep N ==> go north
# pussyfoot north ==> go north
# pussyfoot due north ==> go north
# pussyfoot northward ==> go north
# pussyfoot N ==> go north
# stagger north ==> go north
# stagger due north ==> go north
# stagger northward ==> go north
# stagger N ==> go north
# reel north ==> go north
# reel due north ==> go north
# reel northward ==> go north
# reel N ==> go north
# keel north ==> go north
# keel due north ==> go north
# keel northward ==> go north
# keel N ==> go north
# swag north ==> go north
# swag due north ==> go north
# swag northward ==> go north
# swag N ==> go north
# careen north ==> go north
# careen due north ==> go north
# careen northward ==> go north
# careen N ==> go north
# flounder north ==> go north
# flounder due north ==> go north
# flounder northward ==> go north
# flounder N ==> go north
# step north ==> go north
# step due north ==> go north
# step northward ==> go north
# step N ==> go north
# stomp north ==> go north
# stomp due north ==> go north
# stomp northward ==> go north
# stomp N ==> go north
# stamp north ==> go north
# stamp due north ==> go north
# stamp northward ==> go north
# stamp N ==> go north
# stump north ==> go north
# stump due north ==> go north
# stump northward ==> go north
# stump N ==> go north
# stride north ==> go north
# stride due north ==> go north
# stride northward ==> go north
# stride N ==> go north
# stroll north ==> go north
# stroll due north ==> go north
# stroll northward ==> go north
# stroll N ==> go north
# saunter north ==> go north
# saunter due north ==> go north
# saunter northward ==> go north
# saunter N ==> go north
# stumble north ==> go north
# stumble due north ==> go north
# stumble northward ==> go north
# stumble N ==> go north
# falter north ==> go north
# falter due north ==> go north
# falter northward ==> go north
# falter N ==> go north
# bumble north ==> go north
# bumble due north ==> go north
# bumble northward ==> go north
# bumble N ==> go north
# tap north ==> go north
# tap due north ==> go north
# tap northward ==> go north
# tap N ==> go north
# tiptoe north ==> go north
# tiptoe due north ==> go north
# tiptoe northward ==> go north
# tiptoe N ==> go north
# tip north ==> go north
# tip due north ==> go north
# tip northward ==> go north
# tip N ==> go north
# tippytoe north ==> go north
# tippytoe due north ==> go north
# tippytoe northward ==> go north
# tippytoe N ==> go north
# tittup north ==> go north
# tittup due north ==> go north
# tittup northward ==> go north
# tittup N ==> go north
# swagger north ==> go north
# swagger due north ==> go north
# swagger northward ==> go north
# swagger N ==> go north
# ruffle north ==> go north
# ruffle due north ==> go north
# ruffle northward ==> go north
# ruffle N ==> go north
# strut north ==> go north
# strut due north ==> go north
# strut northward ==> go north
# strut N ==> go north
# sashay north ==> go north
# sashay due north ==> go north
# sashay northward ==> go north
# sashay N ==> go north
# cock north ==> go north
# cock due north ==> go north
# cock northward ==> go north
# cock N ==> go north
# toddle north ==> go north
# toddle due north ==> go north
# toddle northward ==> go north
# toddle N ==> go north
# coggle north ==> go north
# coggle due north ==> go north
# coggle northward ==> go north
# coggle N ==> go north
# totter north ==> go north
# totter due north ==> go north
# totter northward ==> go north
# totter N ==> go north
# dodder north ==> go north
# dodder due north ==> go north
# dodder northward ==> go north
# dodder N ==> go north
# paddle north ==> go north
# paddle due north ==> go north
# paddle northward ==> go north
# paddle N ==> go north
# waddle north ==> go north
# waddle due north ==> go north
# waddle northward ==> go north
# waddle N ==> go north
# tread north ==> go north
# tread due north ==> go north
# tread northward ==> go north
# tread N ==> go north
# trample north ==> go north
# trample due north ==> go north
# trample northward ==> go north
# trample N ==> go north
# wade north ==> go north
# wade due north ==> go north
# wade northward ==> go north
# wade N ==> go north
# jog north ==> go north
# jog due north ==> go north
# jog northward ==> go north
# jog N ==> go north
# lope north ==> go north
# lope due north ==> go north
# lope northward ==> go north
# lope N ==> go north
# romp north ==> go north
# romp due north ==> go north
# romp northward ==> go north
# romp N ==> go north
# scurry north ==> go north
# scurry due north ==> go north
# scurry northward ==> go north
# scurry N ==> go north
# scamper north ==> go north
# scamper due north ==> go north
# scamper northward ==> go north
# scamper N ==> go north
# scuttle north ==> go north
# scuttle due north ==> go north
# scuttle northward ==> go north
# scuttle N ==> go north
# sprint north ==> go north
# sprint due north ==> go north
# sprint northward ==> go north
# sprint N ==> go north
# streak north ==> go north
# streak due north ==> go north
# streak northward ==> go north
# streak N ==> go north
# trot north ==> go north
# trot due north ==> go north
# trot northward ==> go north
# trot N ==> go north
# clip north ==> go north
# clip due north ==> go north
# clip northward ==> go north
# clip N ==> go north
# Congratulations you can now handle 1515 commands instead of just 7!
